# %%
import pandas as pd
import time
import joblib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier, DistanceMetric
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# %%
def split(strt,fnsh,df):
    X_test = df['text'].iloc[strt:fnsh+1]
    y_test = df['label'].iloc[strt:fnsh+1].astype('int')
    df = df.drop(df.index[strt:fnsh])
    X_train = df['text']
    y_train = df['label'].astype('int')
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## CLASSIFER

# %%
def classifier(df,distance_name,k_neighbor):
    print("Nama distance=",distance_name)
    print("Jumlah K tetangga=",k_neighbor)
    spl = [0,108,216,324,432,540,648,756,864,972,1080]
    # spl = [0,216,432,648,864,1080]
    tempspl,acc_score,pre_score,rec_score,f_score = [],[],[],[],[]
    i = 0
    akurasimax=0
    kf = KFold(n_splits=10)
    for train_index, test_index in kf.split(df):
        dfX = df
        X_train, X_test, y_train, y_test = split(test_index[0],test_index[len(test_index)-1],dfX)

#     while (i<len(spl)-1):
# #         --------------Split-------------------
#         if len(spl)-2 != len(tempspl):
#             X_train, X_test, y_train, y_test = split(spl[i],spl[i+2],df)
#             tempspl.append(spl[i])
#     #   ketika array[i+2] == null (looping terakhir)
#         elif (len(spl)-len(tempspl)) == 2:
#     #       split last and first
#             X_test1 = df['text'].iloc[spl[i]:spl[i+1]]
#             y_test1 = df['label'].iloc[spl[i]:spl[i+1]].astype('int')
#             X_test2 = df['text'].iloc[tempspl[0]:tempspl[1]]
#             y_test2 = df['label'].iloc[tempspl[0]:tempspl[1]].astype('int')
#     #       concat last and first
#             X_test = pd.concat([X_test1, X_test2], axis=0)
#             y_test = pd.concat([y_test1, y_test2], axis=0)
#     #       split except last and first
#             X_train = df['text'].iloc[tempspl[1]:tempspl[len(tempspl)-1]]
#             y_train = df['label'].iloc[tempspl[1]:tempspl[len(tempspl)-1]].astype('int')
        
#         --------------Pembobotan TF-ID-------------------
        vectorizer = TfidfVectorizer(min_df=3, dtype=np.double, norm='l2', sublinear_tf=True)
        # vectorizer = TfidfVectorizer()
        X_train = vectorizer.fit_transform(X_train)
        X_test = vectorizer.transform(X_test)

#         --------------CLasifier KNN-------------------        
        modelknn = KNeighborsClassifier(n_neighbors=k_neighbor, weights='distance', metric=distance_name)
        modelknn.fit(X_train,y_train)
        y_pred = modelknn.predict(X_test)
#         print(classification_report(y_test,y_pred))
        akurasi = modelknn.score(X_test, y_test)
        precision = precision_score(y_test,y_pred,average='weighted', labels=np.unique(y_pred))
        recall = recall_score(y_test, y_pred, average='weighted')
        f1score = f1_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
        acc_score.append(akurasi)
        pre_score.append(precision)
        rec_score.append(recall)
        f_score.append(f1score)
        print("Fold ke-",i+1,"Akurasi =","{:.4f}".format(akurasi),
              "Precision =","{:.4f}".format(precision),
              "Recall =","{:.4f}".format(recall),
              "F1-Score =","{:.4f}".format(f1score))
        # if (k_neighbor >= 13):
        #   print(classification_report(y_test,y_pred))
        if (akurasi >= akurasimax):
            akurasimax = akurasi
            foldke = i+1
        i+=1
    avg_acc_score = sum(acc_score)/10
    avg_precision_score = sum(pre_score)/10
    avg_recall_score = sum(rec_score)/10
    avg_f1_score = sum(f_score)/10
    print("Avg accuracy =","{:.4f}".format(avg_acc_score),
          "Avg precision=","{:.4f}".format(avg_precision_score),
          "Avg recall=","{:.4f}".format(avg_recall_score),
          "Avg f1 Score=","{:.4f}".format(avg_f1_score))
    print("Akurasi terbaik adalah",akurasimax,"pada fold ke-",foldke)
    print("------------------------------------")
    return avg_acc_score

# %% [markdown]
# ## sastrawiSW

# %%
# %%time
df = pd.read_pickle('drive/MyDrive/AATABISMILLAH/NewDataset/preprocess_SWsastrawi_stemming.pkl')
dfNo = pd.read_pickle('drive/MyDrive/AATABISMILLAH/NewDataset/preprocess_SWsastrawi_nostemming.pkl')
start_time = time.time()
dfcount = [df,dfNo]
# cosine
distancecount = ['euclidean','manhattan','cosine']
kcount = [1,3,5,7,9,11,13,15]
for x in range(2):
    arrd1 = []
    arrd2 = []
    arrd3 = []
    for y in range(len(distancecount)):
        maxresult = []
        for z in range(len(kcount)):
            if x==0:
                print('Dengan Stemming')
            else:
                print('Tanpa Stemming')
            tempmax = classifier(dfcount[x],distancecount[y],kcount[z])
            maxresult.append(tempmax)
            if y==0:
                arrd1.append(tempmax)
            elif y==1:
                arrd2.append(tempmax)
            elif y==2:
                arrd3.append(tempmax)
#         tapi fold yang dipakai beda beda
    plt.plot(kcount, arrd1, label = "euclidean")
    plt.plot(kcount, arrd2, label = "manhattan")
    plt.plot(kcount, arrd3, label = "cosine")
    plt.xticks(kcount)
    if x==0:
        plt.title("Stemming")
    else:
        plt.title("Tidak Stemming")
    plt.xlabel('Fold')
    plt.ylabel('Akurasi')
    plt.legend()
    plt.pause(0.05)
plt.show
plt.style.use('seaborn-whitegrid')
print("Lama Proses %s seconds" % (time.time() - start_time))
# with open('5000_fitur_SWnltkv2.txt', 'w') as f:
#     f.write(cap.stdout)
# Out:
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.6812 Recall = 0.1204 F1-Score = 0.1601
# Fold ke- 2 Akurasi = 0.1389 Precision = 0.8480 Recall = 0.1389 F1-Score = 0.2210
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.6159 Recall = 0.5926 F1-Score = 0.5760
# Fold ke- 4 Akurasi = 0.1944 Precision = 0.8618 Recall = 0.1944 F1-Score = 0.2806
# Fold ke- 5 Akurasi = 0.2037 Precision = 0.8707 Recall = 0.2037 F1-Score = 0.3520
# Fold ke- 6 Akurasi = 0.2778 Precision = 0.8719 Recall = 0.2778 F1-Score = 0.4826
# Fold ke- 7 Akurasi = 0.2593 Precision = 0.8529 Recall = 0.2593 F1-Score = 0.3685
# Fold ke- 8 Akurasi = 0.1944 Precision = 0.7596 Recall = 0.1944 F1-Score = 0.2384
# Fold ke- 9 Akurasi = 0.2037 Precision = 0.7043 Recall = 0.2037 F1-Score = 0.3243
# Fold ke- 10 Akurasi = 0.2037 Precision = 0.8038 Recall = 0.2037 F1-Score = 0.3028
# Avg accuracy = 0.2389 Avg precision= 0.7870 Avg recall= 0.2389 Avg f1 Score= 0.3306
# Akurasi terbaik adalah 0.5925925925925926 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.4815 Precision = 0.7102 Recall = 0.4815 F1-Score = 0.5350
# Fold ke- 2 Akurasi = 0.4722 Precision = 0.7862 Recall = 0.4722 F1-Score = 0.5184
# Fold ke- 3 Akurasi = 0.6296 Precision = 0.6762 Recall = 0.6296 F1-Score = 0.6123
# Fold ke- 4 Akurasi = 0.5556 Precision = 0.8171 Recall = 0.5556 F1-Score = 0.6127
# Fold ke- 5 Akurasi = 0.6944 Precision = 0.8609 Recall = 0.6944 F1-Score = 0.7395
# Fold ke- 6 Akurasi = 0.6667 Precision = 0.8627 Recall = 0.6667 F1-Score = 0.6945
# Fold ke- 7 Akurasi = 0.7130 Precision = 0.8886 Recall = 0.7130 F1-Score = 0.7314
# Fold ke- 8 Akurasi = 0.6759 Precision = 0.8224 Recall = 0.6759 F1-Score = 0.6957
# Fold ke- 9 Akurasi = 0.6389 Precision = 0.7718 Recall = 0.6389 F1-Score = 0.6575
# Fold ke- 10 Akurasi = 0.6204 Precision = 0.8991 Recall = 0.6204 F1-Score = 0.6617
# Avg accuracy = 0.6148 Avg precision= 0.8095 Avg recall= 0.6148 Avg f1 Score= 0.6459
# Akurasi terbaik adalah 0.7129629629629629 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7037 Precision = 0.7373 Recall = 0.7037 F1-Score = 0.6978
# Fold ke- 2 Akurasi = 0.6574 Precision = 0.6983 Recall = 0.6574 F1-Score = 0.6600
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.7129 Recall = 0.6667 F1-Score = 0.6595
# Fold ke- 4 Akurasi = 0.7130 Precision = 0.7453 Recall = 0.7130 F1-Score = 0.7142
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.7955 Recall = 0.7870 F1-Score = 0.7839
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8994 Recall = 0.8889 F1-Score = 0.8888
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8606 Recall = 0.8241 F1-Score = 0.8178
# Fold ke- 8 Akurasi = 0.7593 Precision = 0.7767 Recall = 0.7593 F1-Score = 0.7528
# Fold ke- 9 Akurasi = 0.7037 Precision = 0.7329 Recall = 0.7037 F1-Score = 0.7011
# Fold ke- 10 Akurasi = 0.7407 Precision = 0.7787 Recall = 0.7407 F1-Score = 0.7269
# Avg accuracy = 0.7444 Avg precision= 0.7738 Avg recall= 0.7444 Avg f1 Score= 0.7403
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7315 Precision = 0.7673 Recall = 0.7315 F1-Score = 0.7304
# Fold ke- 2 Akurasi = 0.6852 Precision = 0.7019 Recall = 0.6852 F1-Score = 0.6721
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6769 Recall = 0.6574 F1-Score = 0.6439
# Fold ke- 4 Akurasi = 0.7315 Precision = 0.7486 Recall = 0.7315 F1-Score = 0.7283
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8198 Recall = 0.7963 F1-Score = 0.7966
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9227 Recall = 0.9074 F1-Score = 0.9092
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8588 Recall = 0.8241 F1-Score = 0.8171
# Fold ke- 8 Akurasi = 0.7685 Precision = 0.7781 Recall = 0.7685 F1-Score = 0.7598
# Fold ke- 9 Akurasi = 0.7500 Precision = 0.7887 Recall = 0.7500 F1-Score = 0.7453
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8160 Recall = 0.7870 F1-Score = 0.7795
# Avg accuracy = 0.7639 Avg precision= 0.7879 Avg recall= 0.7639 Avg f1 Score= 0.7582
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7631 Recall = 0.7407 F1-Score = 0.7375
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7217 Recall = 0.7037 F1-Score = 0.6895
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6632 Recall = 0.6574 F1-Score = 0.6412
# Fold ke- 4 Akurasi = 0.7500 Precision = 0.7640 Recall = 0.7500 F1-Score = 0.7471
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8284 Recall = 0.7870 F1-Score = 0.7864
# Fold ke- 6 Akurasi = 0.8611 Precision = 0.8769 Recall = 0.8611 F1-Score = 0.8610
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8628 Recall = 0.8241 F1-Score = 0.8204
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.7948 Recall = 0.7870 F1-Score = 0.7779
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8197 Recall = 0.7870 F1-Score = 0.7810
# Fold ke- 10 Akurasi = 0.7685 Precision = 0.7973 Recall = 0.7685 F1-Score = 0.7578
# Avg accuracy = 0.7667 Avg precision= 0.7892 Avg recall= 0.7667 Avg f1 Score= 0.7600
# Akurasi terbaik adalah 0.8611111111111112 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7645 Recall = 0.7407 F1-Score = 0.7376
# Fold ke- 2 Akurasi = 0.6852 Precision = 0.7090 Recall = 0.6852 F1-Score = 0.6726
# Fold ke- 3 Akurasi = 0.6481 Precision = 0.6622 Recall = 0.6481 F1-Score = 0.6343
# Fold ke- 4 Akurasi = 0.7685 Precision = 0.8002 Recall = 0.7685 F1-Score = 0.7709
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8077 Recall = 0.7778 F1-Score = 0.7782
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8854 Recall = 0.8704 F1-Score = 0.8716
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8671 Recall = 0.8333 F1-Score = 0.8219
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.7974 Recall = 0.7870 F1-Score = 0.7781
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8260 Recall = 0.7963 F1-Score = 0.7938
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8145 Recall = 0.7963 F1-Score = 0.7898
# Avg accuracy = 0.7704 Avg precision= 0.7934 Avg recall= 0.7704 Avg f1 Score= 0.7649
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7315 Precision = 0.7592 Recall = 0.7315 F1-Score = 0.7263
# Fold ke- 2 Akurasi = 0.6759 Precision = 0.7046 Recall = 0.6759 F1-Score = 0.6608
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6952 Recall = 0.6759 F1-Score = 0.6632
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8058 Recall = 0.7778 F1-Score = 0.7804
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8064 Recall = 0.7778 F1-Score = 0.7778
# Fold ke- 6 Akurasi = 0.8148 Precision = 0.8266 Recall = 0.8148 F1-Score = 0.8101
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8672 Recall = 0.8241 F1-Score = 0.8136
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.8002 Recall = 0.7870 F1-Score = 0.7809
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8279 Recall = 0.7963 F1-Score = 0.7902
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8235 Recall = 0.7963 F1-Score = 0.7931
# Avg accuracy = 0.7657 Avg precision= 0.7917 Avg recall= 0.7657 Avg f1 Score= 0.7596
# Akurasi terbaik adalah 0.8240740740740741 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7130 Precision = 0.7321 Recall = 0.7130 F1-Score = 0.7008
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7281 Recall = 0.6944 F1-Score = 0.6847
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6985 Recall = 0.6759 F1-Score = 0.6646
# Fold ke- 4 Akurasi = 0.7593 Precision = 0.7858 Recall = 0.7593 F1-Score = 0.7614
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7983 Recall = 0.7685 F1-Score = 0.7679
# Fold ke- 6 Akurasi = 0.8148 Precision = 0.8519 Recall = 0.8148 F1-Score = 0.8135
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8720 Recall = 0.8333 F1-Score = 0.8223
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8158 Recall = 0.8056 F1-Score = 0.7991
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8198 Recall = 0.7870 F1-Score = 0.7810
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8328 Recall = 0.8056 F1-Score = 0.8009
# Avg accuracy = 0.7657 Avg precision= 0.7935 Avg recall= 0.7657 Avg f1 Score= 0.7596
# Akurasi terbaik adalah 0.8333333333333334 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 4 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 5 Akurasi = 0.1574 Precision = 0.8483 Recall = 0.1574 F1-Score = 0.2760
# Fold ke- 6 Akurasi = 0.1852 Precision = 0.8186 Recall = 0.1852 F1-Score = 0.3895
# Fold ke- 7 Akurasi = 0.1667 Precision = 0.7930 Recall = 0.1667 F1-Score = 0.2316
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.7880 Recall = 0.1667 F1-Score = 0.2106
# Fold ke- 9 Akurasi = 0.1389 Precision = 0.8480 Recall = 0.1389 F1-Score = 0.2210
# Fold ke- 10 Akurasi = 0.1574 Precision = 0.7750 Recall = 0.1574 F1-Score = 0.2375
# Avg accuracy = 0.1407 Avg precision= 0.7743 Avg recall= 0.1407 Avg f1 Score= 0.2313
# Akurasi terbaik adalah 0.18518518518518517 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1944 Precision = 0.8069 Recall = 0.1944 F1-Score = 0.2615
# Fold ke- 4 Akurasi = 0.1296 Precision = 0.8479 Recall = 0.1296 F1-Score = 0.1935
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.8703 Recall = 0.1759 F1-Score = 0.2851
# Fold ke- 6 Akurasi = 0.2315 Precision = 0.8711 Recall = 0.2315 F1-Score = 0.4028
# Fold ke- 7 Akurasi = 0.2130 Precision = 0.8523 Recall = 0.2130 F1-Score = 0.2857
# Fold ke- 8 Akurasi = 0.1759 Precision = 0.8865 Recall = 0.1759 F1-Score = 0.2574
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.5842 Recall = 0.1296 F1-Score = 0.1610
# Fold ke- 10 Akurasi = 0.1667 Precision = 0.7988 Recall = 0.1667 F1-Score = 0.2591
# Avg accuracy = 0.1630 Avg precision= 0.7984 Avg recall= 0.1630 Avg f1 Score= 0.2481
# Akurasi terbaik adalah 0.23148148148148148 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.5214 Recall = 0.1019 F1-Score = 0.1395
# Fold ke- 3 Akurasi = 0.2500 Precision = 0.6911 Recall = 0.2500 F1-Score = 0.3065
# Fold ke- 4 Akurasi = 0.1296 Precision = 0.8479 Recall = 0.1296 F1-Score = 0.1935
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.8703 Recall = 0.1759 F1-Score = 0.2851
# Fold ke- 6 Akurasi = 0.2222 Precision = 0.8871 Recall = 0.2222 F1-Score = 0.3337
# Fold ke- 7 Akurasi = 0.2315 Precision = 0.8624 Recall = 0.2315 F1-Score = 0.3491
# Fold ke- 8 Akurasi = 0.2222 Precision = 0.8398 Recall = 0.2222 F1-Score = 0.2835
# Fold ke- 9 Akurasi = 0.1204 Precision = 0.6175 Recall = 0.1204 F1-Score = 0.1849
# Fold ke- 10 Akurasi = 0.1481 Precision = 0.8482 Recall = 0.1481 F1-Score = 0.2439
# Avg accuracy = 0.1713 Avg precision= 0.7757 Avg recall= 0.1713 Avg f1 Score= 0.2509
# Akurasi terbaik adalah 0.25 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.6468 Recall = 0.1204 F1-Score = 0.2265
# Fold ke- 2 Akurasi = 0.1111 Precision = 0.4417 Recall = 0.1111 F1-Score = 0.1843
# Fold ke- 3 Akurasi = 0.3426 Precision = 0.6767 Recall = 0.3426 F1-Score = 0.3821
# Fold ke- 4 Akurasi = 0.1481 Precision = 0.7246 Recall = 0.1481 F1-Score = 0.2107
# Fold ke- 5 Akurasi = 0.2130 Precision = 0.7991 Recall = 0.2130 F1-Score = 0.3298
# Fold ke- 6 Akurasi = 0.2778 Precision = 0.7722 Recall = 0.2778 F1-Score = 0.4314
# Fold ke- 7 Akurasi = 0.3056 Precision = 0.8167 Recall = 0.3056 F1-Score = 0.3563
# Fold ke- 8 Akurasi = 0.2407 Precision = 0.8388 Recall = 0.2407 F1-Score = 0.3267
# Fold ke- 9 Akurasi = 0.1944 Precision = 0.7279 Recall = 0.1944 F1-Score = 0.2496
# Fold ke- 10 Akurasi = 0.2315 Precision = 0.8087 Recall = 0.2315 F1-Score = 0.3398
# Avg accuracy = 0.2185 Avg precision= 0.7253 Avg recall= 0.2185 Avg f1 Score= 0.3037
# Akurasi terbaik adalah 0.3425925925925926 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.1389 Precision = 0.6477 Recall = 0.1389 F1-Score = 0.2826
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.3010 Recall = 0.1019 F1-Score = 0.1202
# Fold ke- 3 Akurasi = 0.3333 Precision = 0.6838 Recall = 0.3333 F1-Score = 0.3805
# Fold ke- 4 Akurasi = 0.1667 Precision = 0.7853 Recall = 0.1667 F1-Score = 0.2282
# Fold ke- 5 Akurasi = 0.2130 Precision = 0.8454 Recall = 0.2130 F1-Score = 0.3236
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.7436 Recall = 0.2407 F1-Score = 0.4350
# Fold ke- 7 Akurasi = 0.3056 Precision = 0.8377 Recall = 0.3056 F1-Score = 0.3598
# Fold ke- 8 Akurasi = 0.2407 Precision = 0.8510 Recall = 0.2407 F1-Score = 0.3206
# Fold ke- 9 Akurasi = 0.2037 Precision = 0.7155 Recall = 0.2037 F1-Score = 0.2790
# Fold ke- 10 Akurasi = 0.2407 Precision = 0.8815 Recall = 0.2407 F1-Score = 0.3347
# Avg accuracy = 0.2185 Avg precision= 0.7292 Avg recall= 0.2185 Avg f1 Score= 0.3064
# Akurasi terbaik adalah 0.3333333333333333 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.1389 Precision = 0.5714 Recall = 0.1389 F1-Score = 0.2506
# Fold ke- 2 Akurasi = 0.1111 Precision = 0.5178 Recall = 0.1111 F1-Score = 0.1491
# Fold ke- 3 Akurasi = 0.3056 Precision = 0.6732 Recall = 0.3056 F1-Score = 0.3335
# Fold ke- 4 Akurasi = 0.2037 Precision = 0.8078 Recall = 0.2037 F1-Score = 0.3073
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.8710 Recall = 0.2222 F1-Score = 0.3831
# Fold ke- 6 Akurasi = 0.2593 Precision = 0.8255 Recall = 0.2593 F1-Score = 0.4231
# Fold ke- 7 Akurasi = 0.3148 Precision = 0.8585 Recall = 0.3148 F1-Score = 0.3737
# Fold ke- 8 Akurasi = 0.2500 Precision = 0.8511 Recall = 0.2500 F1-Score = 0.3360
# Fold ke- 9 Akurasi = 0.2315 Precision = 0.8238 Recall = 0.2315 F1-Score = 0.3847
# Fold ke- 10 Akurasi = 0.2407 Precision = 0.8564 Recall = 0.2407 F1-Score = 0.3506
# Avg accuracy = 0.2278 Avg precision= 0.7657 Avg recall= 0.2278 Avg f1 Score= 0.3292
# Akurasi terbaik adalah 0.3148148148148148 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.1574 Precision = 0.4601 Recall = 0.1574 F1-Score = 0.1810
# Fold ke- 2 Akurasi = 0.1296 Precision = 0.6258 Recall = 0.1296 F1-Score = 0.1887
# Fold ke- 3 Akurasi = 0.3241 Precision = 0.6733 Recall = 0.3241 F1-Score = 0.3871
# Fold ke- 4 Akurasi = 0.1759 Precision = 0.7966 Recall = 0.1759 F1-Score = 0.2307
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.8141 Recall = 0.2222 F1-Score = 0.3695
# Fold ke- 6 Akurasi = 0.2685 Precision = 0.7771 Recall = 0.2685 F1-Score = 0.4688
# Fold ke- 7 Akurasi = 0.3241 Precision = 0.8643 Recall = 0.3241 F1-Score = 0.3878
# Fold ke- 8 Akurasi = 0.2593 Precision = 0.8363 Recall = 0.2593 F1-Score = 0.3391
# Fold ke- 9 Akurasi = 0.2593 Precision = 0.8261 Recall = 0.2593 F1-Score = 0.3728
# Fold ke- 10 Akurasi = 0.2407 Precision = 0.8256 Recall = 0.2407 F1-Score = 0.3494
# Avg accuracy = 0.2361 Avg precision= 0.7499 Avg recall= 0.2361 Avg f1 Score= 0.3275
# Akurasi terbaik adalah 0.32407407407407407 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.1296 Precision = 0.3454 Recall = 0.1296 F1-Score = 0.1535
# Fold ke- 2 Akurasi = 0.1481 Precision = 0.6484 Recall = 0.1481 F1-Score = 0.2181
# Fold ke- 3 Akurasi = 0.3056 Precision = 0.6840 Recall = 0.3056 F1-Score = 0.3548
# Fold ke- 4 Akurasi = 0.2130 Precision = 0.7699 Recall = 0.2130 F1-Score = 0.2774
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.7300 Recall = 0.2222 F1-Score = 0.3291
# Fold ke- 6 Akurasi = 0.2778 Precision = 0.7776 Recall = 0.2778 F1-Score = 0.3940
# Fold ke- 7 Akurasi = 0.3333 Precision = 0.8361 Recall = 0.3333 F1-Score = 0.3633
# Fold ke- 8 Akurasi = 0.2778 Precision = 0.8192 Recall = 0.2778 F1-Score = 0.3389
# Fold ke- 9 Akurasi = 0.3056 Precision = 0.8077 Recall = 0.3056 F1-Score = 0.4136
# Fold ke- 10 Akurasi = 0.2778 Precision = 0.8137 Recall = 0.2778 F1-Score = 0.3386
# Avg accuracy = 0.2491 Avg precision= 0.7232 Avg recall= 0.2491 Avg f1 Score= 0.3181
# Akurasi terbaik adalah 0.3333333333333333 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.6204 Precision = 0.6283 Recall = 0.6204 F1-Score = 0.6065
# Fold ke- 2 Akurasi = 0.6204 Precision = 0.6272 Recall = 0.6204 F1-Score = 0.6198
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.6111 Recall = 0.5926 F1-Score = 0.5767
# Fold ke- 4 Akurasi = 0.6759 Precision = 0.7220 Recall = 0.6759 F1-Score = 0.6741
# Fold ke- 5 Akurasi = 0.7407 Precision = 0.7545 Recall = 0.7407 F1-Score = 0.7398
# Fold ke- 6 Akurasi = 0.8519 Precision = 0.8695 Recall = 0.8519 F1-Score = 0.8518
# Fold ke- 7 Akurasi = 0.8056 Precision = 0.8117 Recall = 0.8056 F1-Score = 0.7993
# Fold ke- 8 Akurasi = 0.7500 Precision = 0.7686 Recall = 0.7500 F1-Score = 0.7392
# Fold ke- 9 Akurasi = 0.6944 Precision = 0.7072 Recall = 0.6944 F1-Score = 0.6849
# Fold ke- 10 Akurasi = 0.7130 Precision = 0.7389 Recall = 0.7130 F1-Score = 0.7048
# Avg accuracy = 0.7065 Avg precision= 0.7239 Avg recall= 0.7065 Avg f1 Score= 0.6997
# Akurasi terbaik adalah 0.8518518518518519 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.6574 Precision = 0.6730 Recall = 0.6574 F1-Score = 0.6516
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7015 Recall = 0.6944 F1-Score = 0.6929
# Fold ke- 3 Akurasi = 0.6296 Precision = 0.6378 Recall = 0.6296 F1-Score = 0.6131
# Fold ke- 4 Akurasi = 0.7130 Precision = 0.7281 Recall = 0.7130 F1-Score = 0.7118
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7839 Recall = 0.7685 F1-Score = 0.7670
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8916 Recall = 0.8796 F1-Score = 0.8798
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8346 Recall = 0.8148 F1-Score = 0.8064
# Fold ke- 8 Akurasi = 0.7685 Precision = 0.7759 Recall = 0.7685 F1-Score = 0.7579
# Fold ke- 9 Akurasi = 0.7130 Precision = 0.7299 Recall = 0.7130 F1-Score = 0.7089
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8146 Recall = 0.7870 F1-Score = 0.7753
# Avg accuracy = 0.7426 Avg precision= 0.7571 Avg recall= 0.7426 Avg f1 Score= 0.7365
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.6852 Precision = 0.7233 Recall = 0.6852 F1-Score = 0.6811
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7306 Recall = 0.7130 F1-Score = 0.7075
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.7027 Recall = 0.6667 F1-Score = 0.6600
# Fold ke- 4 Akurasi = 0.7500 Precision = 0.7767 Recall = 0.7500 F1-Score = 0.7512
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8161 Recall = 0.7963 F1-Score = 0.7960
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9256 Recall = 0.9074 F1-Score = 0.9097
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8760 Recall = 0.8426 F1-Score = 0.8371
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8153 Recall = 0.8056 F1-Score = 0.7994
# Fold ke- 9 Akurasi = 0.7500 Precision = 0.7759 Recall = 0.7500 F1-Score = 0.7450
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8291 Recall = 0.7963 F1-Score = 0.7938
# Avg accuracy = 0.7713 Avg precision= 0.7971 Avg recall= 0.7713 Avg f1 Score= 0.7681
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7739 Recall = 0.7407 F1-Score = 0.7406
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7485 Recall = 0.7130 F1-Score = 0.7022
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6661 Recall = 0.6574 F1-Score = 0.6446
# Fold ke- 4 Akurasi = 0.7593 Precision = 0.7819 Recall = 0.7593 F1-Score = 0.7614
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8342 Recall = 0.7963 F1-Score = 0.7964
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8898 Recall = 0.8704 F1-Score = 0.8712
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8596 Recall = 0.8148 F1-Score = 0.8122
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8214 Recall = 0.8148 F1-Score = 0.8088
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8023 Recall = 0.7778 F1-Score = 0.7730
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8234 Recall = 0.7963 F1-Score = 0.7883
# Avg accuracy = 0.7741 Avg precision= 0.8001 Avg recall= 0.7741 Avg f1 Score= 0.7699
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7733 Recall = 0.7407 F1-Score = 0.7411
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7364 Recall = 0.7037 F1-Score = 0.6896
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6627 Recall = 0.6574 F1-Score = 0.6406
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8009 Recall = 0.7778 F1-Score = 0.7770
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8244 Recall = 0.7963 F1-Score = 0.7966
# Fold ke- 6 Akurasi = 0.8519 Precision = 0.8692 Recall = 0.8519 F1-Score = 0.8520
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8604 Recall = 0.8241 F1-Score = 0.8135
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8191 Recall = 0.8056 F1-Score = 0.7996
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8236 Recall = 0.7963 F1-Score = 0.7901
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8321 Recall = 0.8056 F1-Score = 0.8010
# Avg accuracy = 0.7759 Avg precision= 0.8002 Avg recall= 0.7759 Avg f1 Score= 0.7701
# Akurasi terbaik adalah 0.8518518518518519 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.7835 Recall = 0.7593 F1-Score = 0.7559
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7386 Recall = 0.6944 F1-Score = 0.6850
# Fold ke- 3 Akurasi = 0.6481 Precision = 0.6617 Recall = 0.6481 F1-Score = 0.6337
# Fold ke- 4 Akurasi = 0.7870 Precision = 0.8100 Recall = 0.7870 F1-Score = 0.7873
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7997 Recall = 0.7685 F1-Score = 0.7682
# Fold ke- 6 Akurasi = 0.8611 Precision = 0.8704 Recall = 0.8611 F1-Score = 0.8599
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8723 Recall = 0.8333 F1-Score = 0.8238
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8234 Recall = 0.8148 F1-Score = 0.8081
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8286 Recall = 0.8056 F1-Score = 0.8021
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8415 Recall = 0.8241 F1-Score = 0.8187
# Avg accuracy = 0.7796 Avg precision= 0.8030 Avg recall= 0.7796 Avg f1 Score= 0.7743
# Akurasi terbaik adalah 0.8611111111111112 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7130 Precision = 0.7339 Recall = 0.7130 F1-Score = 0.7012
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7573 Recall = 0.7130 F1-Score = 0.7012
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6969 Recall = 0.6759 F1-Score = 0.6640
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8066 Recall = 0.7778 F1-Score = 0.7798
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7983 Recall = 0.7685 F1-Score = 0.7679
# Fold ke- 6 Akurasi = 0.8426 Precision = 0.8728 Recall = 0.8426 F1-Score = 0.8419
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8672 Recall = 0.8241 F1-Score = 0.8136
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8269 Recall = 0.8148 F1-Score = 0.8085
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8330 Recall = 0.8056 F1-Score = 0.7979
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8444 Recall = 0.8148 F1-Score = 0.8088
# Avg accuracy = 0.7750 Avg precision= 0.8037 Avg recall= 0.7750 Avg f1 Score= 0.7685
# Akurasi terbaik adalah 0.8425925925925926 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7222 Precision = 0.7430 Recall = 0.7222 F1-Score = 0.7162
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7717 Recall = 0.7222 F1-Score = 0.7157
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.7000 Recall = 0.6759 F1-Score = 0.6655
# Fold ke- 4 Akurasi = 0.7685 Precision = 0.7900 Recall = 0.7685 F1-Score = 0.7725
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8008 Recall = 0.7778 F1-Score = 0.7762
# Fold ke- 6 Akurasi = 0.8241 Precision = 0.8588 Recall = 0.8241 F1-Score = 0.8239
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8631 Recall = 0.8148 F1-Score = 0.8034
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8376 Recall = 0.8241 F1-Score = 0.8180
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8425 Recall = 0.8056 F1-Score = 0.7979
# Fold ke- 10 Akurasi = 0.8426 Precision = 0.8676 Recall = 0.8426 F1-Score = 0.8399
# Avg accuracy = 0.7778 Avg precision= 0.8075 Avg recall= 0.7778 Avg f1 Score= 0.7729
# Akurasi terbaik adalah 0.8425925925925926 pada fold ke- 10
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 3 Akurasi = 0.5741 Precision = 0.5863 Recall = 0.5741 F1-Score = 0.5638
# Fold ke- 4 Akurasi = 0.1389 Precision = 0.7926 Recall = 0.1389 F1-Score = 0.2162
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.8486 Recall = 0.1759 F1-Score = 0.3265
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8713 Recall = 0.2407 F1-Score = 0.4084
# Fold ke- 7 Akurasi = 0.2037 Precision = 0.8331 Recall = 0.2037 F1-Score = 0.2798
# Fold ke- 8 Akurasi = 0.1944 Precision = 0.8095 Recall = 0.1944 F1-Score = 0.2400
# Fold ke- 9 Akurasi = 0.1667 Precision = 0.8485 Recall = 0.1667 F1-Score = 0.2944
# Fold ke- 10 Akurasi = 0.1852 Precision = 0.7754 Recall = 0.1852 F1-Score = 0.2975
# Avg accuracy = 0.2093 Avg precision= 0.7725 Avg recall= 0.2093 Avg f1 Score= 0.2996
# Akurasi terbaik adalah 0.5740740740740741 pada fold ke- 3
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.5093 Precision = 0.7837 Recall = 0.5093 F1-Score = 0.5428
# Fold ke- 2 Akurasi = 0.4907 Precision = 0.7047 Recall = 0.4907 F1-Score = 0.5258
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.5931 Recall = 0.5926 F1-Score = 0.5826
# Fold ke- 4 Akurasi = 0.5648 Precision = 0.8199 Recall = 0.5648 F1-Score = 0.6125
# Fold ke- 5 Akurasi = 0.7222 Precision = 0.8756 Recall = 0.7222 F1-Score = 0.7620
# Fold ke- 6 Akurasi = 0.6759 Precision = 0.9202 Recall = 0.6759 F1-Score = 0.7125
# Fold ke- 7 Akurasi = 0.7130 Precision = 0.8936 Recall = 0.7130 F1-Score = 0.7391
# Fold ke- 8 Akurasi = 0.6574 Precision = 0.8368 Recall = 0.6574 F1-Score = 0.6861
# Fold ke- 9 Akurasi = 0.6481 Precision = 0.8199 Recall = 0.6481 F1-Score = 0.6861
# Fold ke- 10 Akurasi = 0.5926 Precision = 0.8647 Recall = 0.5926 F1-Score = 0.6277
# Avg accuracy = 0.6167 Avg precision= 0.8112 Avg recall= 0.6167 Avg f1 Score= 0.6477
# Akurasi terbaik adalah 0.7222222222222222 pada fold ke- 5
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7577 Recall = 0.7407 F1-Score = 0.7300
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7168 Recall = 0.7037 F1-Score = 0.6994
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6799 Recall = 0.6667 F1-Score = 0.6580
# Fold ke- 4 Akurasi = 0.7315 Precision = 0.7738 Recall = 0.7315 F1-Score = 0.7339
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8211 Recall = 0.8056 F1-Score = 0.8058
# Fold ke- 6 Akurasi = 0.8981 Precision = 0.9151 Recall = 0.8981 F1-Score = 0.8999
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8667 Recall = 0.8333 F1-Score = 0.8264
# Fold ke- 8 Akurasi = 0.7778 Precision = 0.7998 Recall = 0.7778 F1-Score = 0.7738
# Fold ke- 9 Akurasi = 0.7407 Precision = 0.7782 Recall = 0.7407 F1-Score = 0.7423
# Fold ke- 10 Akurasi = 0.7685 Precision = 0.8102 Recall = 0.7685 F1-Score = 0.7616
# Avg accuracy = 0.7667 Avg precision= 0.7919 Avg recall= 0.7667 Avg f1 Score= 0.7631
# Akurasi terbaik adalah 0.8981481481481481 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7222 Precision = 0.7263 Recall = 0.7222 F1-Score = 0.6982
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7299 Recall = 0.7222 F1-Score = 0.7125
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6785 Recall = 0.6667 F1-Score = 0.6572
# Fold ke- 4 Akurasi = 0.7685 Precision = 0.7773 Recall = 0.7685 F1-Score = 0.7660
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8473 Recall = 0.8148 F1-Score = 0.8168
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9169 Recall = 0.9074 F1-Score = 0.9065
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8771 Recall = 0.8426 F1-Score = 0.8373
# Fold ke- 8 Akurasi = 0.7963 Precision = 0.8128 Recall = 0.7963 F1-Score = 0.7869
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7943 Recall = 0.7685 F1-Score = 0.7653
# Fold ke- 10 Akurasi = 0.8333 Precision = 0.8703 Recall = 0.8333 F1-Score = 0.8312
# Avg accuracy = 0.7843 Avg precision= 0.8031 Avg recall= 0.7843 Avg f1 Score= 0.7778
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7549 Recall = 0.7407 F1-Score = 0.7323
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7466 Recall = 0.7222 F1-Score = 0.7139
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.6911 Recall = 0.6852 F1-Score = 0.6751
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8170 Recall = 0.8056 F1-Score = 0.8079
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8422 Recall = 0.8148 F1-Score = 0.8155
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8987 Recall = 0.8889 F1-Score = 0.8887
# Fold ke- 7 Akurasi = 0.7963 Precision = 0.8113 Recall = 0.7963 F1-Score = 0.7892
# Fold ke- 8 Akurasi = 0.7685 Precision = 0.7900 Recall = 0.7685 F1-Score = 0.7601
# Fold ke- 9 Akurasi = 0.7593 Precision = 0.7941 Recall = 0.7593 F1-Score = 0.7576
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8627 Recall = 0.8241 F1-Score = 0.8194
# Avg accuracy = 0.7806 Avg precision= 0.8009 Avg recall= 0.7806 Avg f1 Score= 0.7760
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.7791 Recall = 0.7593 F1-Score = 0.7527
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7220 Recall = 0.7037 F1-Score = 0.6952
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.7061 Recall = 0.6944 F1-Score = 0.6825
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8258 Recall = 0.8056 F1-Score = 0.8087
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8335 Recall = 0.8056 F1-Score = 0.8070
# Fold ke- 6 Akurasi = 0.8611 Precision = 0.8768 Recall = 0.8611 F1-Score = 0.8630
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8408 Recall = 0.8241 F1-Score = 0.8166
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.8081 Recall = 0.7870 F1-Score = 0.7788
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.8022 Recall = 0.7685 F1-Score = 0.7625
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8349 Recall = 0.8056 F1-Score = 0.8020
# Avg accuracy = 0.7815 Avg precision= 0.8029 Avg recall= 0.7815 Avg f1 Score= 0.7769
# Akurasi terbaik adalah 0.8611111111111112 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7704 Recall = 0.7500 F1-Score = 0.7402
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7523 Recall = 0.7315 F1-Score = 0.7201
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.7078 Recall = 0.6944 F1-Score = 0.6832
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8191 Recall = 0.7963 F1-Score = 0.7980
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8374 Recall = 0.8148 F1-Score = 0.8151
# Fold ke- 6 Akurasi = 0.8333 Precision = 0.8536 Recall = 0.8333 F1-Score = 0.8329
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8747 Recall = 0.8426 F1-Score = 0.8319
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8248 Recall = 0.8056 F1-Score = 0.7994
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8205 Recall = 0.7870 F1-Score = 0.7807
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8431 Recall = 0.8056 F1-Score = 0.8054
# Avg accuracy = 0.7861 Avg precision= 0.8104 Avg recall= 0.7861 Avg f1 Score= 0.7807
# Akurasi terbaik adalah 0.8425925925925926 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7542 Recall = 0.7407 F1-Score = 0.7314
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7516 Recall = 0.7315 F1-Score = 0.7169
# Fold ke- 3 Akurasi = 0.7222 Precision = 0.7355 Recall = 0.7222 F1-Score = 0.7139
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8284 Recall = 0.8056 F1-Score = 0.8072
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8104 Recall = 0.7870 F1-Score = 0.7840
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8966 Recall = 0.8796 F1-Score = 0.8798
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8747 Recall = 0.8426 F1-Score = 0.8319
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8217 Recall = 0.8056 F1-Score = 0.7966
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8205 Recall = 0.7870 F1-Score = 0.7807
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8358 Recall = 0.8056 F1-Score = 0.8018
# Avg accuracy = 0.7907 Avg precision= 0.8129 Avg recall= 0.7907 Avg f1 Score= 0.7844
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1111 Precision = 0.6173 Recall = 0.1111 F1-Score = 0.1519
# Fold ke- 4 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 5 Akurasi = 0.1574 Precision = 0.8483 Recall = 0.1574 F1-Score = 0.2760
# Fold ke- 6 Akurasi = 0.1667 Precision = 0.8182 Recall = 0.1667 F1-Score = 0.3461
# Fold ke- 7 Akurasi = 0.1481 Precision = 0.8237 Recall = 0.1481 F1-Score = 0.1934
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.8864 Recall = 0.1667 F1-Score = 0.2367
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.8175 Recall = 0.1296 F1-Score = 0.2249
# Fold ke- 10 Akurasi = 0.1296 Precision = 0.6815 Recall = 0.1296 F1-Score = 0.1879
# Avg accuracy = 0.1315 Avg precision= 0.7501 Avg recall= 0.1315 Avg f1 Score= 0.2169
# Akurasi terbaik adalah 0.16666666666666666 pada fold ke- 8
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1574 Precision = 0.7512 Recall = 0.1574 F1-Score = 0.2353
# Fold ke- 4 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 5 Akurasi = 0.1574 Precision = 0.8483 Recall = 0.1574 F1-Score = 0.2760
# Fold ke- 6 Akurasi = 0.1944 Precision = 0.8490 Recall = 0.1944 F1-Score = 0.3690
# Fold ke- 7 Akurasi = 0.1574 Precision = 0.8434 Recall = 0.1574 F1-Score = 0.1943
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.8864 Recall = 0.1667 F1-Score = 0.2367
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.8175 Recall = 0.1296 F1-Score = 0.2249
# Fold ke- 10 Akurasi = 0.1296 Precision = 0.6815 Recall = 0.1296 F1-Score = 0.1879
# Avg accuracy = 0.1398 Avg precision= 0.7686 Avg recall= 0.1398 Avg f1 Score= 0.2277
# Akurasi terbaik adalah 0.19444444444444445 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 2 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 3 Akurasi = 0.1852 Precision = 0.7112 Recall = 0.1852 F1-Score = 0.2694
# Fold ke- 4 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.8703 Recall = 0.1759 F1-Score = 0.2851
# Fold ke- 6 Akurasi = 0.2130 Precision = 0.8493 Recall = 0.2130 F1-Score = 0.4053
# Fold ke- 7 Akurasi = 0.2130 Precision = 0.8621 Recall = 0.2130 F1-Score = 0.3159
# Fold ke- 8 Akurasi = 0.1759 Precision = 0.8865 Recall = 0.1759 F1-Score = 0.2540
# Fold ke- 9 Akurasi = 0.1204 Precision = 0.7716 Recall = 0.1204 F1-Score = 0.2307
# Fold ke- 10 Akurasi = 0.1389 Precision = 0.8176 Recall = 0.1389 F1-Score = 0.2524
# Avg accuracy = 0.1537 Avg precision= 0.7823 Avg recall= 0.1537 Avg f1 Score= 0.2568
# Akurasi terbaik adalah 0.21296296296296297 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.6952 Recall = 0.1111 F1-Score = 0.2405
# Fold ke- 2 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 3 Akurasi = 0.2037 Precision = 0.6303 Recall = 0.2037 F1-Score = 0.2455
# Fold ke- 4 Akurasi = 0.1296 Precision = 0.8479 Recall = 0.1296 F1-Score = 0.1935
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.7617 Recall = 0.1759 F1-Score = 0.2498
# Fold ke- 6 Akurasi = 0.2315 Precision = 0.8356 Recall = 0.2315 F1-Score = 0.3865
# Fold ke- 7 Akurasi = 0.2315 Precision = 0.8628 Recall = 0.2315 F1-Score = 0.3243
# Fold ke- 8 Akurasi = 0.1944 Precision = 0.8867 Recall = 0.1944 F1-Score = 0.2893
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.6814 Recall = 0.1296 F1-Score = 0.1876
# Fold ke- 10 Akurasi = 0.1667 Precision = 0.8701 Recall = 0.1667 F1-Score = 0.2615
# Avg accuracy = 0.1667 Avg precision= 0.7614 Avg recall= 0.1667 Avg f1 Score= 0.2556
# Akurasi terbaik adalah 0.23148148148148148 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.7716 Recall = 0.1204 F1-Score = 0.2307
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.4733 Recall = 0.1019 F1-Score = 0.1753
# Fold ke- 3 Akurasi = 0.1852 Precision = 0.5989 Recall = 0.1852 F1-Score = 0.2170
# Fold ke- 4 Akurasi = 0.1389 Precision = 0.7650 Recall = 0.1389 F1-Score = 0.2121
# Fold ke- 5 Akurasi = 0.2037 Precision = 0.8868 Recall = 0.2037 F1-Score = 0.3065
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8498 Recall = 0.2407 F1-Score = 0.4597
# Fold ke- 7 Akurasi = 0.2593 Precision = 0.8475 Recall = 0.2593 F1-Score = 0.3499
# Fold ke- 8 Akurasi = 0.2222 Precision = 0.8184 Recall = 0.2222 F1-Score = 0.3264
# Fold ke- 9 Akurasi = 0.1574 Precision = 0.5303 Recall = 0.1574 F1-Score = 0.2588
# Fold ke- 10 Akurasi = 0.1944 Precision = 0.8453 Recall = 0.1944 F1-Score = 0.2760
# Avg accuracy = 0.1824 Avg precision= 0.7387 Avg recall= 0.1824 Avg f1 Score= 0.2812
# Akurasi terbaik adalah 0.25925925925925924 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.7716 Recall = 0.1204 F1-Score = 0.2307
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.4184 Recall = 0.1019 F1-Score = 0.1136
# Fold ke- 3 Akurasi = 0.1667 Precision = 0.5802 Recall = 0.1667 F1-Score = 0.2189
# Fold ke- 4 Akurasi = 0.1481 Precision = 0.7635 Recall = 0.1481 F1-Score = 0.2012
# Fold ke- 5 Akurasi = 0.2130 Precision = 0.8100 Recall = 0.2130 F1-Score = 0.3461
# Fold ke- 6 Akurasi = 0.2685 Precision = 0.8061 Recall = 0.2685 F1-Score = 0.4938
# Fold ke- 7 Akurasi = 0.2778 Precision = 0.8391 Recall = 0.2778 F1-Score = 0.3631
# Fold ke- 8 Akurasi = 0.2407 Precision = 0.8313 Recall = 0.2407 F1-Score = 0.3415
# Fold ke- 9 Akurasi = 0.2500 Precision = 0.8127 Recall = 0.2500 F1-Score = 0.3745
# Fold ke- 10 Akurasi = 0.2037 Precision = 0.8422 Recall = 0.2037 F1-Score = 0.3391
# Avg accuracy = 0.1991 Avg precision= 0.7475 Avg recall= 0.1991 Avg f1 Score= 0.3023
# Akurasi terbaik adalah 0.2777777777777778 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.1481 Precision = 0.7225 Recall = 0.1481 F1-Score = 0.3251
# Fold ke- 2 Akurasi = 0.1111 Precision = 0.5165 Recall = 0.1111 F1-Score = 0.1793
# Fold ke- 3 Akurasi = 0.2593 Precision = 0.6679 Recall = 0.2593 F1-Score = 0.2958
# Fold ke- 4 Akurasi = 0.1574 Precision = 0.7814 Recall = 0.1574 F1-Score = 0.2180
# Fold ke- 5 Akurasi = 0.2407 Precision = 0.8336 Recall = 0.2407 F1-Score = 0.3261
# Fold ke- 6 Akurasi = 0.2500 Precision = 0.7962 Recall = 0.2500 F1-Score = 0.4634
# Fold ke- 7 Akurasi = 0.2500 Precision = 0.8316 Recall = 0.2500 F1-Score = 0.3273
# Fold ke- 8 Akurasi = 0.2315 Precision = 0.8153 Recall = 0.2315 F1-Score = 0.3263
# Fold ke- 9 Akurasi = 0.2593 Precision = 0.7734 Recall = 0.2593 F1-Score = 0.3375
# Fold ke- 10 Akurasi = 0.2315 Precision = 0.7992 Recall = 0.2315 F1-Score = 0.3418
# Avg accuracy = 0.2139 Avg precision= 0.7538 Avg recall= 0.2139 Avg f1 Score= 0.3141
# Akurasi terbaik adalah 0.25925925925925924 pada fold ke- 9
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.1481 Precision = 0.4109 Recall = 0.1481 F1-Score = 0.2133
# Fold ke- 2 Akurasi = 0.1481 Precision = 0.6547 Recall = 0.1481 F1-Score = 0.2339
# Fold ke- 3 Akurasi = 0.2778 Precision = 0.6850 Recall = 0.2778 F1-Score = 0.3099
# Fold ke- 4 Akurasi = 0.1667 Precision = 0.7824 Recall = 0.1667 F1-Score = 0.2311
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.8141 Recall = 0.2222 F1-Score = 0.3695
# Fold ke- 6 Akurasi = 0.2500 Precision = 0.8500 Recall = 0.2500 F1-Score = 0.4787
# Fold ke- 7 Akurasi = 0.2778 Precision = 0.8391 Recall = 0.2778 F1-Score = 0.3688
# Fold ke- 8 Akurasi = 0.2407 Precision = 0.8510 Recall = 0.2407 F1-Score = 0.3206
# Fold ke- 9 Akurasi = 0.2130 Precision = 0.7208 Recall = 0.2130 F1-Score = 0.2890
# Fold ke- 10 Akurasi = 0.2037 Precision = 0.8233 Recall = 0.2037 F1-Score = 0.3339
# Avg accuracy = 0.2148 Avg precision= 0.7431 Avg recall= 0.2148 Avg f1 Score= 0.3149
# Akurasi terbaik adalah 0.2777777777777778 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.6204 Precision = 0.6301 Recall = 0.6204 F1-Score = 0.6078
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7098 Recall = 0.7037 F1-Score = 0.6978
# Fold ke- 3 Akurasi = 0.5741 Precision = 0.5863 Recall = 0.5741 F1-Score = 0.5638
# Fold ke- 4 Akurasi = 0.6759 Precision = 0.7248 Recall = 0.6759 F1-Score = 0.6707
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7833 Recall = 0.7685 F1-Score = 0.7679
# Fold ke- 6 Akurasi = 0.8241 Precision = 0.8493 Recall = 0.8241 F1-Score = 0.8239
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8446 Recall = 0.8241 F1-Score = 0.8152
# Fold ke- 8 Akurasi = 0.7685 Precision = 0.7790 Recall = 0.7685 F1-Score = 0.7569
# Fold ke- 9 Akurasi = 0.7315 Precision = 0.7488 Recall = 0.7315 F1-Score = 0.7284
# Fold ke- 10 Akurasi = 0.7222 Precision = 0.7500 Recall = 0.7222 F1-Score = 0.7107
# Avg accuracy = 0.7213 Avg precision= 0.7406 Avg recall= 0.7213 Avg f1 Score= 0.7143
# Akurasi terbaik adalah 0.8240740740740741 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.7037 Precision = 0.7132 Recall = 0.7037 F1-Score = 0.6935
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7254 Recall = 0.7222 F1-Score = 0.7188
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.5931 Recall = 0.5926 F1-Score = 0.5826
# Fold ke- 4 Akurasi = 0.7315 Precision = 0.7447 Recall = 0.7315 F1-Score = 0.7281
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.7992 Recall = 0.7870 F1-Score = 0.7857
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8888 Recall = 0.8704 F1-Score = 0.8743
# Fold ke- 7 Akurasi = 0.8056 Precision = 0.8221 Recall = 0.8056 F1-Score = 0.8015
# Fold ke- 8 Akurasi = 0.7963 Precision = 0.8042 Recall = 0.7963 F1-Score = 0.7903
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7865 Recall = 0.7685 F1-Score = 0.7676
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8262 Recall = 0.7870 F1-Score = 0.7784
# Avg accuracy = 0.7565 Avg precision= 0.7703 Avg recall= 0.7565 Avg f1 Score= 0.7521
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7619 Recall = 0.7407 F1-Score = 0.7280
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7241 Recall = 0.7222 F1-Score = 0.7114
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6747 Recall = 0.6667 F1-Score = 0.6582
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8108 Recall = 0.8056 F1-Score = 0.8024
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8356 Recall = 0.8056 F1-Score = 0.8068
# Fold ke- 6 Akurasi = 0.8981 Precision = 0.9082 Recall = 0.8981 F1-Score = 0.8987
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8771 Recall = 0.8426 F1-Score = 0.8373
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8343 Recall = 0.8241 F1-Score = 0.8178
# Fold ke- 9 Akurasi = 0.7593 Precision = 0.7778 Recall = 0.7593 F1-Score = 0.7577
# Fold ke- 10 Akurasi = 0.8333 Precision = 0.8694 Recall = 0.8333 F1-Score = 0.8301
# Avg accuracy = 0.7898 Avg precision= 0.8074 Avg recall= 0.7898 Avg f1 Score= 0.7848
# Akurasi terbaik adalah 0.8981481481481481 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7522 Recall = 0.7407 F1-Score = 0.7283
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7459 Recall = 0.7315 F1-Score = 0.7213
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6733 Recall = 0.6667 F1-Score = 0.6573
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8044 Recall = 0.7963 F1-Score = 0.7955
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8342 Recall = 0.7870 F1-Score = 0.7886
# Fold ke- 6 Akurasi = 0.8981 Precision = 0.9092 Recall = 0.8981 F1-Score = 0.8990
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8698 Recall = 0.8333 F1-Score = 0.8296
# Fold ke- 8 Akurasi = 0.7778 Precision = 0.7967 Recall = 0.7778 F1-Score = 0.7703
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.8018 Recall = 0.7685 F1-Score = 0.7664
# Fold ke- 10 Akurasi = 0.8519 Precision = 0.8858 Recall = 0.8519 F1-Score = 0.8511
# Avg accuracy = 0.7852 Avg precision= 0.8073 Avg recall= 0.7852 Avg f1 Score= 0.7808
# Akurasi terbaik adalah 0.8981481481481481 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7575 Recall = 0.7407 F1-Score = 0.7258
# Fold ke- 2 Akurasi = 0.7407 Precision = 0.7770 Recall = 0.7407 F1-Score = 0.7366
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.6989 Recall = 0.6852 F1-Score = 0.6738
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8159 Recall = 0.7963 F1-Score = 0.7998
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8400 Recall = 0.8148 F1-Score = 0.8160
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.9018 Recall = 0.8889 F1-Score = 0.8907
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8388 Recall = 0.8241 F1-Score = 0.8158
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8371 Recall = 0.8241 F1-Score = 0.8190
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7987 Recall = 0.7685 F1-Score = 0.7664
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8450 Recall = 0.8241 F1-Score = 0.8227
# Avg accuracy = 0.7907 Avg precision= 0.8111 Avg recall= 0.7907 Avg f1 Score= 0.7867
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7646 Recall = 0.7500 F1-Score = 0.7408
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7636 Recall = 0.7315 F1-Score = 0.7228
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.7288 Recall = 0.6944 F1-Score = 0.6818
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8329 Recall = 0.8056 F1-Score = 0.8116
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8235 Recall = 0.7963 F1-Score = 0.7971
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8821 Recall = 0.8704 F1-Score = 0.8690
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8690 Recall = 0.8333 F1-Score = 0.8229
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8387 Recall = 0.8241 F1-Score = 0.8196
# Fold ke- 9 Akurasi = 0.8148 Precision = 0.8413 Recall = 0.8148 F1-Score = 0.8119
# Fold ke- 10 Akurasi = 0.8426 Precision = 0.8665 Recall = 0.8426 F1-Score = 0.8417
# Avg accuracy = 0.7963 Avg precision= 0.8211 Avg recall= 0.7963 Avg f1 Score= 0.7919
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7694 Recall = 0.7500 F1-Score = 0.7432
# Fold ke- 2 Akurasi = 0.7593 Precision = 0.7905 Recall = 0.7593 F1-Score = 0.7449
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.7295 Recall = 0.6944 F1-Score = 0.6822
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8266 Recall = 0.8056 F1-Score = 0.8086
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8102 Recall = 0.7778 F1-Score = 0.7796
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8960 Recall = 0.8796 F1-Score = 0.8791
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8747 Recall = 0.8426 F1-Score = 0.8319
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8382 Recall = 0.8241 F1-Score = 0.8161
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8214 Recall = 0.7963 F1-Score = 0.7936
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8473 Recall = 0.8148 F1-Score = 0.8146
# Avg accuracy = 0.7944 Avg precision= 0.8204 Avg recall= 0.7944 Avg f1 Score= 0.7894
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.7745 Recall = 0.7593 F1-Score = 0.7532
# Fold ke- 2 Akurasi = 0.7407 Precision = 0.7579 Recall = 0.7407 F1-Score = 0.7260
# Fold ke- 3 Akurasi = 0.7222 Precision = 0.7568 Recall = 0.7222 F1-Score = 0.7130
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.7985 Recall = 0.7778 F1-Score = 0.7811
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7980 Recall = 0.7685 F1-Score = 0.7662
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.9085 Recall = 0.8889 F1-Score = 0.8899
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8766 Recall = 0.8426 F1-Score = 0.8327
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8467 Recall = 0.8241 F1-Score = 0.8174
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8248 Recall = 0.7870 F1-Score = 0.7840
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8456 Recall = 0.8148 F1-Score = 0.8103
# Avg accuracy = 0.7926 Avg precision= 0.8188 Avg recall= 0.7926 Avg f1 Score= 0.7874
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Lama Proses 173.09387230873108 seconds
# CPU times: user 3min 50s, sys: 1.84 s, total: 3min 52s
# Wall time: 2min 53s

# %% [markdown]
# ## nltkSW

# %%
# %%time
df = pd.read_pickle('drive/MyDrive/AATABISMILLAH/NewDataset/preprocess_SWnltk_stemming.pkl')
dfNo = pd.read_pickle('drive/MyDrive/AATABISMILLAH/NewDataset/preprocess_SWnltk_nostemming.pkl')
# %%capture cap --no-stderr
start_time = time.time()
dfcount = [df,dfNo]
distancecount = ['euclidean','manhattan','cosine']
kcount = [1,3,5,7,9,11,13,15]
for x in range(2):
    arrd1 = []
    arrd2 = []
    arrd3 = []
    for y in range(len(distancecount)):
        maxresult = []
        for z in range(len(kcount)):
            if x==0:
                print('Dengan Stemming')
            else:
                print('Tanpa Stemming')
            tempmax = classifier(dfcount[x],distancecount[y],kcount[z])
            maxresult.append(tempmax)
            if y==0:
                arrd1.append(tempmax)
            elif y==1:
                arrd2.append(tempmax)
            elif y==2:
                arrd3.append(tempmax)
#         tapi fold yang dipakai beda beda
    plt.plot(kcount, arrd1, label = "euclidean")
    plt.plot(kcount, arrd2, label = "manhattan")
    plt.plot(kcount, arrd3, label = "cosine")
    plt.xticks(kcount)
    if x==0:
        plt.title("Stemming")
    else:
        plt.title("Tidak Stemming")
    plt.xlabel('Fold')
    plt.ylabel('Akurasi')
    plt.legend()
    plt.pause(0.05)
plt.show
plt.style.use('seaborn-whitegrid')
print("Lama Proses %s seconds" % (time.time() - start_time))
# with open('5000_fitur_SWnltkv2.txt', 'w') as f:
#     f.write(cap.stdout)
# Out:
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.6812 Recall = 0.1204 F1-Score = 0.1601
# Fold ke- 2 Akurasi = 0.1481 Precision = 0.8699 Recall = 0.1481 F1-Score = 0.2182
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.6264 Recall = 0.5926 F1-Score = 0.5768
# Fold ke- 4 Akurasi = 0.2037 Precision = 0.8773 Recall = 0.2037 F1-Score = 0.2718
# Fold ke- 5 Akurasi = 0.2315 Precision = 0.8628 Recall = 0.2315 F1-Score = 0.3338
# Fold ke- 6 Akurasi = 0.3056 Precision = 0.8884 Recall = 0.3056 F1-Score = 0.4829
# Fold ke- 7 Akurasi = 0.2778 Precision = 0.8608 Recall = 0.2778 F1-Score = 0.3630
# Fold ke- 8 Akurasi = 0.2130 Precision = 0.7666 Recall = 0.2130 F1-Score = 0.2445
# Fold ke- 9 Akurasi = 0.2037 Precision = 0.7043 Recall = 0.2037 F1-Score = 0.3243
# Fold ke- 10 Akurasi = 0.2130 Precision = 0.8039 Recall = 0.2130 F1-Score = 0.3174
# Avg accuracy = 0.2509 Avg precision= 0.7942 Avg recall= 0.2509 Avg f1 Score= 0.3293
# Akurasi terbaik adalah 0.5925925925925926 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.4630 Precision = 0.7095 Recall = 0.4630 F1-Score = 0.4802
# Fold ke- 2 Akurasi = 0.5000 Precision = 0.7475 Recall = 0.5000 F1-Score = 0.5441
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6809 Recall = 0.6667 F1-Score = 0.6479
# Fold ke- 4 Akurasi = 0.5833 Precision = 0.8144 Recall = 0.5833 F1-Score = 0.6370
# Fold ke- 5 Akurasi = 0.6852 Precision = 0.8457 Recall = 0.6852 F1-Score = 0.7227
# Fold ke- 6 Akurasi = 0.7407 Precision = 0.8679 Recall = 0.7407 F1-Score = 0.7523
# Fold ke- 7 Akurasi = 0.7222 Precision = 0.8772 Recall = 0.7222 F1-Score = 0.7375
# Fold ke- 8 Akurasi = 0.6667 Precision = 0.8082 Recall = 0.6667 F1-Score = 0.6936
# Fold ke- 9 Akurasi = 0.6389 Precision = 0.7862 Recall = 0.6389 F1-Score = 0.6619
# Fold ke- 10 Akurasi = 0.6204 Precision = 0.8247 Recall = 0.6204 F1-Score = 0.6389
# Avg accuracy = 0.6287 Avg precision= 0.7962 Avg recall= 0.6287 Avg f1 Score= 0.6516
# Akurasi terbaik adalah 0.7407407407407407 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.6759 Precision = 0.6922 Recall = 0.6759 F1-Score = 0.6645
# Fold ke- 2 Akurasi = 0.6759 Precision = 0.7029 Recall = 0.6759 F1-Score = 0.6703
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.6812 Recall = 0.6852 F1-Score = 0.6700
# Fold ke- 4 Akurasi = 0.7500 Precision = 0.7699 Recall = 0.7500 F1-Score = 0.7484
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.7940 Recall = 0.7778 F1-Score = 0.7737
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8902 Recall = 0.8796 F1-Score = 0.8784
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8513 Recall = 0.8148 F1-Score = 0.8085
# Fold ke- 8 Akurasi = 0.7315 Precision = 0.7449 Recall = 0.7315 F1-Score = 0.7251
# Fold ke- 9 Akurasi = 0.7037 Precision = 0.7559 Recall = 0.7037 F1-Score = 0.7063
# Fold ke- 10 Akurasi = 0.7593 Precision = 0.7950 Recall = 0.7593 F1-Score = 0.7508
# Avg accuracy = 0.7454 Avg precision= 0.7677 Avg recall= 0.7454 Avg f1 Score= 0.7396
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7685 Precision = 0.7828 Recall = 0.7685 F1-Score = 0.7579
# Fold ke- 2 Akurasi = 0.6852 Precision = 0.7004 Recall = 0.6852 F1-Score = 0.6746
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.6998 Recall = 0.6944 F1-Score = 0.6860
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.7969 Recall = 0.7778 F1-Score = 0.7811
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8158 Recall = 0.7870 F1-Score = 0.7866
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9178 Recall = 0.9074 F1-Score = 0.9058
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8527 Recall = 0.8333 F1-Score = 0.8280
# Fold ke- 8 Akurasi = 0.7963 Precision = 0.8156 Recall = 0.7963 F1-Score = 0.7926
# Fold ke- 9 Akurasi = 0.7500 Precision = 0.7924 Recall = 0.7500 F1-Score = 0.7464
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8119 Recall = 0.7870 F1-Score = 0.7817
# Avg accuracy = 0.7787 Avg precision= 0.7986 Avg recall= 0.7787 Avg f1 Score= 0.7741
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.7891 Recall = 0.7593 F1-Score = 0.7500
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7247 Recall = 0.7130 F1-Score = 0.7021
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6593 Recall = 0.6667 F1-Score = 0.6486
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8363 Recall = 0.8056 F1-Score = 0.8108
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8072 Recall = 0.7778 F1-Score = 0.7768
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8870 Recall = 0.8796 F1-Score = 0.8783
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8430 Recall = 0.8333 F1-Score = 0.8219
# Fold ke- 8 Akurasi = 0.7963 Precision = 0.8069 Recall = 0.7963 F1-Score = 0.7874
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8036 Recall = 0.7778 F1-Score = 0.7743
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8158 Recall = 0.7963 F1-Score = 0.7887
# Avg accuracy = 0.7806 Avg precision= 0.7973 Avg recall= 0.7806 Avg f1 Score= 0.7739
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.7920 Recall = 0.7593 F1-Score = 0.7475
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7496 Recall = 0.7315 F1-Score = 0.7204
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.6898 Recall = 0.6944 F1-Score = 0.6801
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8348 Recall = 0.8056 F1-Score = 0.8099
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8273 Recall = 0.7963 F1-Score = 0.7964
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8781 Recall = 0.8704 F1-Score = 0.8689
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8703 Recall = 0.8333 F1-Score = 0.8227
# Fold ke- 8 Akurasi = 0.7963 Precision = 0.8085 Recall = 0.7963 F1-Score = 0.7892
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8332 Recall = 0.8056 F1-Score = 0.8025
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8128 Recall = 0.7963 F1-Score = 0.7902
# Avg accuracy = 0.7889 Avg precision= 0.8096 Avg recall= 0.7889 Avg f1 Score= 0.7828
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7779 Recall = 0.7407 F1-Score = 0.7363
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7071 Recall = 0.6944 F1-Score = 0.6790
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6835 Recall = 0.6759 F1-Score = 0.6544
# Fold ke- 4 Akurasi = 0.8241 Precision = 0.8527 Recall = 0.8241 F1-Score = 0.8281
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8172 Recall = 0.7870 F1-Score = 0.7863
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8920 Recall = 0.8796 F1-Score = 0.8797
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8584 Recall = 0.8148 F1-Score = 0.8052
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8191 Recall = 0.8056 F1-Score = 0.8012
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7986 Recall = 0.7685 F1-Score = 0.7652
# Fold ke- 10 Akurasi = 0.7963 Precision = 0.8132 Recall = 0.7963 F1-Score = 0.7870
# Avg accuracy = 0.7787 Avg precision= 0.8020 Avg recall= 0.7787 Avg f1 Score= 0.7722
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.8169 Recall = 0.7593 F1-Score = 0.7496
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7008 Recall = 0.6944 F1-Score = 0.6796
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6836 Recall = 0.6759 F1-Score = 0.6558
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8315 Recall = 0.7963 F1-Score = 0.8030
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8238 Recall = 0.7963 F1-Score = 0.7938
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8849 Recall = 0.8704 F1-Score = 0.8706
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8714 Recall = 0.8241 F1-Score = 0.8151
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8261 Recall = 0.8148 F1-Score = 0.8090
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8166 Recall = 0.7778 F1-Score = 0.7737
# Fold ke- 10 Akurasi = 0.7778 Precision = 0.7896 Recall = 0.7778 F1-Score = 0.7643
# Avg accuracy = 0.7787 Avg precision= 0.8045 Avg recall= 0.7787 Avg f1 Score= 0.7714
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1574 Precision = 0.8862 Recall = 0.1574 F1-Score = 0.2161
# Fold ke- 4 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 5 Akurasi = 0.1667 Precision = 0.8485 Recall = 0.1667 F1-Score = 0.2990
# Fold ke- 6 Akurasi = 0.2130 Precision = 0.8493 Recall = 0.2130 F1-Score = 0.3958
# Fold ke- 7 Akurasi = 0.1944 Precision = 0.8246 Recall = 0.1944 F1-Score = 0.2834
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.7880 Recall = 0.1667 F1-Score = 0.2106
# Fold ke- 9 Akurasi = 0.1389 Precision = 0.8480 Recall = 0.1389 F1-Score = 0.2210
# Fold ke- 10 Akurasi = 0.1667 Precision = 0.7752 Recall = 0.1667 F1-Score = 0.2611
# Avg accuracy = 0.1519 Avg precision= 0.7874 Avg recall= 0.1519 Avg f1 Score= 0.2442
# Akurasi terbaik adalah 0.21296296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 2 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 3 Akurasi = 0.1944 Precision = 0.8452 Recall = 0.1944 F1-Score = 0.2917
# Fold ke- 4 Akurasi = 0.1389 Precision = 0.8697 Recall = 0.1389 F1-Score = 0.1946
# Fold ke- 5 Akurasi = 0.1944 Precision = 0.8867 Recall = 0.1944 F1-Score = 0.2953
# Fold ke- 6 Akurasi = 0.2778 Precision = 0.8879 Recall = 0.2778 F1-Score = 0.4379
# Fold ke- 7 Akurasi = 0.2407 Precision = 0.8526 Recall = 0.2407 F1-Score = 0.3348
# Fold ke- 8 Akurasi = 0.1852 Precision = 0.8992 Recall = 0.1852 F1-Score = 0.2512
# Fold ke- 9 Akurasi = 0.1574 Precision = 0.7273 Recall = 0.1574 F1-Score = 0.2368
# Fold ke- 10 Akurasi = 0.1852 Precision = 0.8242 Recall = 0.1852 F1-Score = 0.2726
# Avg accuracy = 0.1796 Avg precision= 0.8336 Avg recall= 0.1796 Avg f1 Score= 0.2694
# Akurasi terbaik adalah 0.2777777777777778 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.7714 Recall = 0.1111 F1-Score = 0.1895
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.5214 Recall = 0.1019 F1-Score = 0.1395
# Fold ke- 3 Akurasi = 0.2593 Precision = 0.7264 Recall = 0.2593 F1-Score = 0.3271
# Fold ke- 4 Akurasi = 0.1481 Precision = 0.8861 Recall = 0.1481 F1-Score = 0.1955
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.8871 Recall = 0.2222 F1-Score = 0.3478
# Fold ke- 6 Akurasi = 0.2500 Precision = 0.8668 Recall = 0.2500 F1-Score = 0.3900
# Fold ke- 7 Akurasi = 0.2685 Precision = 0.8903 Recall = 0.2685 F1-Score = 0.3528
# Fold ke- 8 Akurasi = 0.2222 Precision = 0.8775 Recall = 0.2222 F1-Score = 0.3085
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.7718 Recall = 0.1296 F1-Score = 0.2720
# Fold ke- 10 Akurasi = 0.1944 Precision = 0.8705 Recall = 0.1944 F1-Score = 0.3254
# Avg accuracy = 0.1907 Avg precision= 0.8070 Avg recall= 0.1907 Avg f1 Score= 0.2848
# Akurasi terbaik adalah 0.26851851851851855 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.1296 Precision = 0.6896 Recall = 0.1296 F1-Score = 0.2500
# Fold ke- 2 Akurasi = 0.1481 Precision = 0.6223 Recall = 0.1481 F1-Score = 0.1963
# Fold ke- 3 Akurasi = 0.3241 Precision = 0.6873 Recall = 0.3241 F1-Score = 0.3615
# Fold ke- 4 Akurasi = 0.1944 Precision = 0.7969 Recall = 0.1944 F1-Score = 0.2721
# Fold ke- 5 Akurasi = 0.2407 Precision = 0.8042 Recall = 0.2407 F1-Score = 0.3324
# Fold ke- 6 Akurasi = 0.3333 Precision = 0.7851 Recall = 0.3333 F1-Score = 0.4570
# Fold ke- 7 Akurasi = 0.3333 Precision = 0.7992 Recall = 0.3333 F1-Score = 0.4161
# Fold ke- 8 Akurasi = 0.2870 Precision = 0.8333 Recall = 0.2870 F1-Score = 0.3839
# Fold ke- 9 Akurasi = 0.2778 Precision = 0.7662 Recall = 0.2778 F1-Score = 0.3951
# Fold ke- 10 Akurasi = 0.2685 Precision = 0.8414 Recall = 0.2685 F1-Score = 0.3596
# Avg accuracy = 0.2537 Avg precision= 0.7626 Avg recall= 0.2537 Avg f1 Score= 0.3424
# Akurasi terbaik adalah 0.3333333333333333 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.6448 Recall = 0.1204 F1-Score = 0.2542
# Fold ke- 2 Akurasi = 0.1296 Precision = 0.6228 Recall = 0.1296 F1-Score = 0.1797
# Fold ke- 3 Akurasi = 0.3333 Precision = 0.6872 Recall = 0.3333 F1-Score = 0.3756
# Fold ke- 4 Akurasi = 0.1944 Precision = 0.7716 Recall = 0.1944 F1-Score = 0.2969
# Fold ke- 5 Akurasi = 0.2685 Precision = 0.7755 Recall = 0.2685 F1-Score = 0.4162
# Fold ke- 6 Akurasi = 0.3056 Precision = 0.7512 Recall = 0.3056 F1-Score = 0.4679
# Fold ke- 7 Akurasi = 0.3426 Precision = 0.8161 Recall = 0.3426 F1-Score = 0.3926
# Fold ke- 8 Akurasi = 0.2407 Precision = 0.8212 Recall = 0.2407 F1-Score = 0.3282
# Fold ke- 9 Akurasi = 0.2685 Precision = 0.7788 Recall = 0.2685 F1-Score = 0.4215
# Fold ke- 10 Akurasi = 0.2500 Precision = 0.8202 Recall = 0.2500 F1-Score = 0.3670
# Avg accuracy = 0.2454 Avg precision= 0.7489 Avg recall= 0.2454 Avg f1 Score= 0.3500
# Akurasi terbaik adalah 0.3425925925925926 pada fold ke- 7
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.1296 Precision = 0.6144 Recall = 0.1296 F1-Score = 0.2669
# Fold ke- 2 Akurasi = 0.1204 Precision = 0.5983 Recall = 0.1204 F1-Score = 0.1578
# Fold ke- 3 Akurasi = 0.3148 Precision = 0.6239 Recall = 0.3148 F1-Score = 0.3845
# Fold ke- 4 Akurasi = 0.2037 Precision = 0.8371 Recall = 0.2037 F1-Score = 0.2980
# Fold ke- 5 Akurasi = 0.2315 Precision = 0.8029 Recall = 0.2315 F1-Score = 0.3674
# Fold ke- 6 Akurasi = 0.2870 Precision = 0.7897 Recall = 0.2870 F1-Score = 0.4579
# Fold ke- 7 Akurasi = 0.2963 Precision = 0.8437 Recall = 0.2963 F1-Score = 0.3792
# Fold ke- 8 Akurasi = 0.2500 Precision = 0.8558 Recall = 0.2500 F1-Score = 0.3476
# Fold ke- 9 Akurasi = 0.2407 Precision = 0.8105 Recall = 0.2407 F1-Score = 0.4092
# Fold ke- 10 Akurasi = 0.2407 Precision = 0.8684 Recall = 0.2407 F1-Score = 0.3303
# Avg accuracy = 0.2315 Avg precision= 0.7645 Avg recall= 0.2315 Avg f1 Score= 0.3399
# Akurasi terbaik adalah 0.3148148148148148 pada fold ke- 3
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.1481 Precision = 0.4587 Recall = 0.1481 F1-Score = 0.2082
# Fold ke- 2 Akurasi = 0.1389 Precision = 0.5739 Recall = 0.1389 F1-Score = 0.2117
# Fold ke- 3 Akurasi = 0.2870 Precision = 0.6819 Recall = 0.2870 F1-Score = 0.3775
# Fold ke- 4 Akurasi = 0.1574 Precision = 0.7655 Recall = 0.1574 F1-Score = 0.2556
# Fold ke- 5 Akurasi = 0.2407 Precision = 0.7694 Recall = 0.2407 F1-Score = 0.3469
# Fold ke- 6 Akurasi = 0.2593 Precision = 0.8311 Recall = 0.2593 F1-Score = 0.4116
# Fold ke- 7 Akurasi = 0.3056 Precision = 0.8427 Recall = 0.3056 F1-Score = 0.3833
# Fold ke- 8 Akurasi = 0.3056 Precision = 0.8553 Recall = 0.3056 F1-Score = 0.3985
# Fold ke- 9 Akurasi = 0.2593 Precision = 0.8203 Recall = 0.2593 F1-Score = 0.4192
# Fold ke- 10 Akurasi = 0.2315 Precision = 0.8665 Recall = 0.2315 F1-Score = 0.3513
# Avg accuracy = 0.2333 Avg precision= 0.7465 Avg recall= 0.2333 Avg f1 Score= 0.3364
# Akurasi terbaik adalah 0.3055555555555556 pada fold ke- 8
# ------------------------------------
# Dengan Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.1667 Precision = 0.4688 Recall = 0.1667 F1-Score = 0.2256
# Fold ke- 2 Akurasi = 0.1667 Precision = 0.5600 Recall = 0.1667 F1-Score = 0.2173
# Fold ke- 3 Akurasi = 0.2500 Precision = 0.7006 Recall = 0.2500 F1-Score = 0.3400
# Fold ke- 4 Akurasi = 0.2315 Precision = 0.7653 Recall = 0.2315 F1-Score = 0.2758
# Fold ke- 5 Akurasi = 0.2685 Precision = 0.7689 Recall = 0.2685 F1-Score = 0.3729
# Fold ke- 6 Akurasi = 0.2870 Precision = 0.7790 Recall = 0.2870 F1-Score = 0.4033
# Fold ke- 7 Akurasi = 0.3241 Precision = 0.7902 Recall = 0.3241 F1-Score = 0.3656
# Fold ke- 8 Akurasi = 0.3056 Precision = 0.8235 Recall = 0.3056 F1-Score = 0.3657
# Fold ke- 9 Akurasi = 0.3241 Precision = 0.8101 Recall = 0.3241 F1-Score = 0.4479
# Fold ke- 10 Akurasi = 0.2685 Precision = 0.8283 Recall = 0.2685 F1-Score = 0.3292
# Avg accuracy = 0.2593 Avg precision= 0.7295 Avg recall= 0.2593 Avg f1 Score= 0.3343
# Akurasi terbaik adalah 0.32407407407407407 pada fold ke- 9
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.6296 Precision = 0.6531 Recall = 0.6296 F1-Score = 0.6190
# Fold ke- 2 Akurasi = 0.6019 Precision = 0.6080 Recall = 0.6019 F1-Score = 0.5981
# Fold ke- 3 Akurasi = 0.5926 Precision = 0.6274 Recall = 0.5926 F1-Score = 0.5784
# Fold ke- 4 Akurasi = 0.6759 Precision = 0.7220 Recall = 0.6759 F1-Score = 0.6743
# Fold ke- 5 Akurasi = 0.7315 Precision = 0.7475 Recall = 0.7315 F1-Score = 0.7305
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.9051 Recall = 0.8889 F1-Score = 0.8893
# Fold ke- 7 Akurasi = 0.7870 Precision = 0.7931 Recall = 0.7870 F1-Score = 0.7767
# Fold ke- 8 Akurasi = 0.7500 Precision = 0.7554 Recall = 0.7500 F1-Score = 0.7379
# Fold ke- 9 Akurasi = 0.7222 Precision = 0.7415 Recall = 0.7222 F1-Score = 0.7158
# Fold ke- 10 Akurasi = 0.7315 Precision = 0.7718 Recall = 0.7315 F1-Score = 0.7128
# Avg accuracy = 0.7111 Avg precision= 0.7325 Avg recall= 0.7111 Avg f1 Score= 0.7033
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.6944 Precision = 0.7118 Recall = 0.6944 F1-Score = 0.6882
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7139 Recall = 0.6944 F1-Score = 0.6951
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6715 Recall = 0.6667 F1-Score = 0.6494
# Fold ke- 4 Akurasi = 0.7315 Precision = 0.7560 Recall = 0.7315 F1-Score = 0.7340
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.7963 Recall = 0.7778 F1-Score = 0.7736
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8996 Recall = 0.8889 F1-Score = 0.8893
# Fold ke- 7 Akurasi = 0.8056 Precision = 0.8226 Recall = 0.8056 F1-Score = 0.7991
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.7999 Recall = 0.7870 F1-Score = 0.7781
# Fold ke- 9 Akurasi = 0.7407 Precision = 0.7570 Recall = 0.7407 F1-Score = 0.7342
# Fold ke- 10 Akurasi = 0.7778 Precision = 0.8011 Recall = 0.7778 F1-Score = 0.7643
# Avg accuracy = 0.7565 Avg precision= 0.7730 Avg recall= 0.7565 Avg f1 Score= 0.7505
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7789 Recall = 0.7500 F1-Score = 0.7425
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7060 Recall = 0.7037 F1-Score = 0.6932
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.6812 Recall = 0.6852 F1-Score = 0.6700
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.7994 Recall = 0.7778 F1-Score = 0.7808
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8257 Recall = 0.7870 F1-Score = 0.7839
# Fold ke- 6 Akurasi = 0.9259 Precision = 0.9345 Recall = 0.9259 F1-Score = 0.9258
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8539 Recall = 0.8333 F1-Score = 0.8284
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8322 Recall = 0.8241 F1-Score = 0.8158
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.8016 Recall = 0.7685 F1-Score = 0.7662
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8215 Recall = 0.7870 F1-Score = 0.7837
# Avg accuracy = 0.7843 Avg precision= 0.8035 Avg recall= 0.7843 Avg f1 Score= 0.7790
# Akurasi terbaik adalah 0.9259259259259259 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7778 Precision = 0.7952 Recall = 0.7778 F1-Score = 0.7670
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7341 Recall = 0.7222 F1-Score = 0.7121
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.6998 Recall = 0.6944 F1-Score = 0.6860
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8293 Recall = 0.7963 F1-Score = 0.8017
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8103 Recall = 0.7778 F1-Score = 0.7767
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8853 Recall = 0.8796 F1-Score = 0.8792
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8435 Recall = 0.8241 F1-Score = 0.8153
# Fold ke- 8 Akurasi = 0.8333 Precision = 0.8432 Recall = 0.8333 F1-Score = 0.8285
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8300 Recall = 0.8056 F1-Score = 0.8014
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8517 Recall = 0.8241 F1-Score = 0.8203
# Avg accuracy = 0.7935 Avg precision= 0.8122 Avg recall= 0.7935 Avg f1 Score= 0.7888
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7222 Precision = 0.7573 Recall = 0.7222 F1-Score = 0.7126
# Fold ke- 2 Akurasi = 0.6852 Precision = 0.7004 Recall = 0.6852 F1-Score = 0.6709
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6689 Recall = 0.6667 F1-Score = 0.6470
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8418 Recall = 0.8056 F1-Score = 0.8127
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8220 Recall = 0.7870 F1-Score = 0.7865
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8778 Recall = 0.8704 F1-Score = 0.8696
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8771 Recall = 0.8426 F1-Score = 0.8318
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8326 Recall = 0.8241 F1-Score = 0.8165
# Fold ke- 9 Akurasi = 0.8056 Precision = 0.8214 Recall = 0.8056 F1-Score = 0.8018
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8320 Recall = 0.8148 F1-Score = 0.8106
# Avg accuracy = 0.7824 Avg precision= 0.8031 Avg recall= 0.7824 Avg f1 Score= 0.7760
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7970 Recall = 0.7407 F1-Score = 0.7305
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7397 Recall = 0.7130 F1-Score = 0.7028
# Fold ke- 3 Akurasi = 0.6944 Precision = 0.6987 Recall = 0.6944 F1-Score = 0.6782
# Fold ke- 4 Akurasi = 0.8241 Precision = 0.8532 Recall = 0.8241 F1-Score = 0.8284
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8144 Recall = 0.7870 F1-Score = 0.7871
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8804 Recall = 0.8704 F1-Score = 0.8691
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8703 Recall = 0.8333 F1-Score = 0.8227
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8306 Recall = 0.8241 F1-Score = 0.8185
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8195 Recall = 0.7870 F1-Score = 0.7842
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8422 Recall = 0.8241 F1-Score = 0.8208
# Avg accuracy = 0.7898 Avg precision= 0.8146 Avg recall= 0.7898 Avg f1 Score= 0.7842
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.8045 Recall = 0.7500 F1-Score = 0.7397
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7629 Recall = 0.7315 F1-Score = 0.7181
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6830 Recall = 0.6759 F1-Score = 0.6541
# Fold ke- 4 Akurasi = 0.8148 Precision = 0.8497 Recall = 0.8148 F1-Score = 0.8213
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8306 Recall = 0.8056 F1-Score = 0.8040
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8862 Recall = 0.8796 F1-Score = 0.8776
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8771 Recall = 0.8333 F1-Score = 0.8249
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8244 Recall = 0.8148 F1-Score = 0.8104
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8106 Recall = 0.7778 F1-Score = 0.7744
# Fold ke- 10 Akurasi = 0.8333 Precision = 0.8530 Recall = 0.8333 F1-Score = 0.8240
# Avg accuracy = 0.7917 Avg precision= 0.8182 Avg recall= 0.7917 Avg f1 Score= 0.7848
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Dengan Stemming
# Nama distance= cosine
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.8174 Recall = 0.7593 F1-Score = 0.7494
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7584 Recall = 0.7315 F1-Score = 0.7211
# Fold ke- 3 Akurasi = 0.6759 Precision = 0.6813 Recall = 0.6759 F1-Score = 0.6552
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8172 Recall = 0.7778 F1-Score = 0.7815
# Fold ke- 5 Akurasi = 0.7870 Precision = 0.8297 Recall = 0.7870 F1-Score = 0.7846
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8986 Recall = 0.8889 F1-Score = 0.8888
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8771 Recall = 0.8333 F1-Score = 0.8241
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8323 Recall = 0.8148 F1-Score = 0.8096
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8268 Recall = 0.7870 F1-Score = 0.7830
# Fold ke- 10 Akurasi = 0.8333 Precision = 0.8529 Recall = 0.8333 F1-Score = 0.8216
# Avg accuracy = 0.7889 Avg precision= 0.8192 Avg recall= 0.7889 Avg f1 Score= 0.7819
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 2 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 3 Akurasi = 0.6111 Precision = 0.6376 Recall = 0.6111 F1-Score = 0.6007
# Fold ke- 4 Akurasi = 0.1852 Precision = 0.8617 Recall = 0.1852 F1-Score = 0.2633
# Fold ke- 5 Akurasi = 0.2222 Precision = 0.8456 Recall = 0.2222 F1-Score = 0.3477
# Fold ke- 6 Akurasi = 0.2593 Precision = 0.8716 Recall = 0.2593 F1-Score = 0.4518
# Fold ke- 7 Akurasi = 0.2315 Precision = 0.8525 Recall = 0.2315 F1-Score = 0.3194
# Fold ke- 8 Akurasi = 0.1944 Precision = 0.7596 Recall = 0.1944 F1-Score = 0.2384
# Fold ke- 9 Akurasi = 0.1944 Precision = 0.7278 Recall = 0.1944 F1-Score = 0.3073
# Fold ke- 10 Akurasi = 0.1944 Precision = 0.8036 Recall = 0.1944 F1-Score = 0.2855
# Avg accuracy = 0.2315 Avg precision= 0.7872 Avg recall= 0.2315 Avg f1 Score= 0.3191
# Akurasi terbaik adalah 0.6111111111111112 pada fold ke- 3
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.5093 Precision = 0.7507 Recall = 0.5093 F1-Score = 0.5737
# Fold ke- 2 Akurasi = 0.5463 Precision = 0.7382 Recall = 0.5463 F1-Score = 0.5768
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6626 Recall = 0.6574 F1-Score = 0.6424
# Fold ke- 4 Akurasi = 0.6111 Precision = 0.8131 Recall = 0.6111 F1-Score = 0.6467
# Fold ke- 5 Akurasi = 0.6852 Precision = 0.8461 Recall = 0.6852 F1-Score = 0.7280
# Fold ke- 6 Akurasi = 0.7037 Precision = 0.8699 Recall = 0.7037 F1-Score = 0.7361
# Fold ke- 7 Akurasi = 0.7222 Precision = 0.8884 Recall = 0.7222 F1-Score = 0.7419
# Fold ke- 8 Akurasi = 0.6574 Precision = 0.8320 Recall = 0.6574 F1-Score = 0.6924
# Fold ke- 9 Akurasi = 0.6667 Precision = 0.8433 Recall = 0.6667 F1-Score = 0.7037
# Fold ke- 10 Akurasi = 0.6019 Precision = 0.8709 Recall = 0.6019 F1-Score = 0.6344
# Avg accuracy = 0.6361 Avg precision= 0.8115 Avg recall= 0.6361 Avg f1 Score= 0.6676
# Akurasi terbaik adalah 0.7222222222222222 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7130 Precision = 0.7140 Recall = 0.7130 F1-Score = 0.6913
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.7182 Recall = 0.6944 F1-Score = 0.6959
# Fold ke- 3 Akurasi = 0.6296 Precision = 0.6261 Recall = 0.6296 F1-Score = 0.6107
# Fold ke- 4 Akurasi = 0.7407 Precision = 0.7711 Recall = 0.7407 F1-Score = 0.7432
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7904 Recall = 0.7685 F1-Score = 0.7695
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8828 Recall = 0.8704 F1-Score = 0.8714
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8350 Recall = 0.8148 F1-Score = 0.8080
# Fold ke- 8 Akurasi = 0.7778 Precision = 0.8058 Recall = 0.7778 F1-Score = 0.7733
# Fold ke- 9 Akurasi = 0.7593 Precision = 0.7982 Recall = 0.7593 F1-Score = 0.7604
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8372 Recall = 0.7870 F1-Score = 0.7827
# Avg accuracy = 0.7556 Avg precision= 0.7779 Avg recall= 0.7556 Avg f1 Score= 0.7507
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7872 Recall = 0.7500 F1-Score = 0.7332
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.6988 Recall = 0.6944 F1-Score = 0.6868
# Fold ke- 3 Akurasi = 0.6389 Precision = 0.6351 Recall = 0.6389 F1-Score = 0.6191
# Fold ke- 4 Akurasi = 0.7870 Precision = 0.8044 Recall = 0.7870 F1-Score = 0.7888
# Fold ke- 5 Akurasi = 0.7685 Precision = 0.7940 Recall = 0.7685 F1-Score = 0.7687
# Fold ke- 6 Akurasi = 0.9167 Precision = 0.9273 Recall = 0.9167 F1-Score = 0.9165
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8592 Recall = 0.8426 F1-Score = 0.8363
# Fold ke- 8 Akurasi = 0.7778 Precision = 0.7951 Recall = 0.7778 F1-Score = 0.7681
# Fold ke- 9 Akurasi = 0.7593 Precision = 0.7934 Recall = 0.7593 F1-Score = 0.7559
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8452 Recall = 0.8148 F1-Score = 0.8067
# Avg accuracy = 0.7750 Avg precision= 0.7940 Avg recall= 0.7750 Avg f1 Score= 0.7680
# Akurasi terbaik adalah 0.9166666666666666 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.8013 Recall = 0.7593 F1-Score = 0.7503
# Fold ke- 2 Akurasi = 0.6944 Precision = 0.6930 Recall = 0.6944 F1-Score = 0.6786
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6719 Recall = 0.6667 F1-Score = 0.6564
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8255 Recall = 0.7963 F1-Score = 0.8039
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8218 Recall = 0.7963 F1-Score = 0.7942
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8900 Recall = 0.8796 F1-Score = 0.8786
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8771 Recall = 0.8426 F1-Score = 0.8324
# Fold ke- 8 Akurasi = 0.7685 Precision = 0.7784 Recall = 0.7685 F1-Score = 0.7553
# Fold ke- 9 Akurasi = 0.7500 Precision = 0.7761 Recall = 0.7500 F1-Score = 0.7495
# Fold ke- 10 Akurasi = 0.8241 Precision = 0.8569 Recall = 0.8241 F1-Score = 0.8198
# Avg accuracy = 0.7778 Avg precision= 0.7992 Avg recall= 0.7778 Avg f1 Score= 0.7719
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7977 Recall = 0.7500 F1-Score = 0.7426
# Fold ke- 2 Akurasi = 0.7407 Precision = 0.7576 Recall = 0.7407 F1-Score = 0.7289
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.7126 Recall = 0.6852 F1-Score = 0.6726
# Fold ke- 4 Akurasi = 0.8333 Precision = 0.8490 Recall = 0.8333 F1-Score = 0.8367
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8339 Recall = 0.8148 F1-Score = 0.8128
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8957 Recall = 0.8889 F1-Score = 0.8883
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8836 Recall = 0.8426 F1-Score = 0.8338
# Fold ke- 8 Akurasi = 0.7870 Precision = 0.8080 Recall = 0.7870 F1-Score = 0.7804
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7939 Recall = 0.7685 F1-Score = 0.7665
# Fold ke- 10 Akurasi = 0.8056 Precision = 0.8345 Recall = 0.8056 F1-Score = 0.8017
# Avg accuracy = 0.7917 Avg precision= 0.8166 Avg recall= 0.7917 Avg f1 Score= 0.7864
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7778 Precision = 0.8197 Recall = 0.7778 F1-Score = 0.7683
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7641 Recall = 0.7315 F1-Score = 0.7135
# Fold ke- 3 Akurasi = 0.7037 Precision = 0.7379 Recall = 0.7037 F1-Score = 0.6913
# Fold ke- 4 Akurasi = 0.7963 Precision = 0.8237 Recall = 0.7963 F1-Score = 0.8001
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8242 Recall = 0.8056 F1-Score = 0.8027
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8987 Recall = 0.8889 F1-Score = 0.8894
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8725 Recall = 0.8333 F1-Score = 0.8236
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8292 Recall = 0.8148 F1-Score = 0.8070
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8031 Recall = 0.7778 F1-Score = 0.7736
# Fold ke- 10 Akurasi = 0.8519 Precision = 0.8613 Recall = 0.8519 F1-Score = 0.8500
# Avg accuracy = 0.7981 Avg precision= 0.8234 Avg recall= 0.7981 Avg f1 Score= 0.7919
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= euclidean
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7593 Precision = 0.8101 Recall = 0.7593 F1-Score = 0.7507
# Fold ke- 2 Akurasi = 0.7315 Precision = 0.7587 Recall = 0.7315 F1-Score = 0.7194
# Fold ke- 3 Akurasi = 0.7037 Precision = 0.7435 Recall = 0.7037 F1-Score = 0.6950
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8214 Recall = 0.7778 F1-Score = 0.7840
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8326 Recall = 0.8148 F1-Score = 0.8122
# Fold ke- 6 Akurasi = 0.8704 Precision = 0.8806 Recall = 0.8704 F1-Score = 0.8713
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8743 Recall = 0.8333 F1-Score = 0.8245
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8209 Recall = 0.8056 F1-Score = 0.8005
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.8003 Recall = 0.7685 F1-Score = 0.7666
# Fold ke- 10 Akurasi = 0.8333 Precision = 0.8495 Recall = 0.8333 F1-Score = 0.8318
# Avg accuracy = 0.7898 Avg precision= 0.8192 Avg recall= 0.7898 Avg f1 Score= 0.7856
# Akurasi terbaik adalah 0.8703703703703703 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1296 Precision = 0.7269 Recall = 0.1296 F1-Score = 0.1660
# Fold ke- 4 Akurasi = 0.1204 Precision = 0.8173 Recall = 0.1204 F1-Score = 0.1919
# Fold ke- 5 Akurasi = 0.1574 Precision = 0.8483 Recall = 0.1574 F1-Score = 0.2760
# Fold ke- 6 Akurasi = 0.2037 Precision = 0.8491 Recall = 0.2037 F1-Score = 0.3812
# Fold ke- 7 Akurasi = 0.1759 Precision = 0.8241 Recall = 0.1759 F1-Score = 0.2553
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.8864 Recall = 0.1667 F1-Score = 0.2367
# Fold ke- 9 Akurasi = 0.1389 Precision = 0.8480 Recall = 0.1389 F1-Score = 0.2210
# Fold ke- 10 Akurasi = 0.1389 Precision = 0.6817 Recall = 0.1389 F1-Score = 0.2154
# Avg accuracy = 0.1426 Avg precision= 0.7719 Avg recall= 0.1426 Avg f1 Score= 0.2307
# Akurasi terbaik adalah 0.2037037037037037 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 3 Akurasi = 0.1944 Precision = 0.8243 Recall = 0.1944 F1-Score = 0.2932
# Fold ke- 4 Akurasi = 0.1296 Precision = 0.8479 Recall = 0.1296 F1-Score = 0.1935
# Fold ke- 5 Akurasi = 0.1667 Precision = 0.8485 Recall = 0.1667 F1-Score = 0.2990
# Fold ke- 6 Akurasi = 0.2315 Precision = 0.8711 Recall = 0.2315 F1-Score = 0.4028
# Fold ke- 7 Akurasi = 0.2130 Precision = 0.8626 Recall = 0.2130 F1-Score = 0.3001
# Fold ke- 8 Akurasi = 0.1667 Precision = 0.8864 Recall = 0.1667 F1-Score = 0.2367
# Fold ke- 9 Akurasi = 0.1389 Precision = 0.8480 Recall = 0.1389 F1-Score = 0.2210
# Fold ke- 10 Akurasi = 0.1481 Precision = 0.6817 Recall = 0.1481 F1-Score = 0.2381
# Avg accuracy = 0.1583 Avg precision= 0.7908 Avg recall= 0.1583 Avg f1 Score= 0.2548
# Akurasi terbaik adalah 0.23148148148148148 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.1019 Precision = 0.6950 Recall = 0.1019 F1-Score = 0.1855
# Fold ke- 2 Akurasi = 0.1019 Precision = 0.5214 Recall = 0.1019 F1-Score = 0.1395
# Fold ke- 3 Akurasi = 0.2315 Precision = 0.8168 Recall = 0.2315 F1-Score = 0.3241
# Fold ke- 4 Akurasi = 0.1296 Precision = 0.8479 Recall = 0.1296 F1-Score = 0.1935
# Fold ke- 5 Akurasi = 0.1759 Precision = 0.8703 Recall = 0.1759 F1-Score = 0.2851
# Fold ke- 6 Akurasi = 0.2315 Precision = 0.8711 Recall = 0.2315 F1-Score = 0.3998
# Fold ke- 7 Akurasi = 0.2407 Precision = 0.8778 Recall = 0.2407 F1-Score = 0.3328
# Fold ke- 8 Akurasi = 0.1852 Precision = 0.8992 Recall = 0.1852 F1-Score = 0.2482
# Fold ke- 9 Akurasi = 0.1296 Precision = 0.7718 Recall = 0.1296 F1-Score = 0.2720
# Fold ke- 10 Akurasi = 0.1574 Precision = 0.8483 Recall = 0.1574 F1-Score = 0.2634
# Avg accuracy = 0.1685 Avg precision= 0.8020 Avg recall= 0.1685 Avg f1 Score= 0.2644
# Akurasi terbaik adalah 0.24074074074074073 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.6952 Recall = 0.1111 F1-Score = 0.2405
# Fold ke- 2 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 3 Akurasi = 0.2778 Precision = 0.6844 Recall = 0.2778 F1-Score = 0.3497
# Fold ke- 4 Akurasi = 0.1389 Precision = 0.8697 Recall = 0.1389 F1-Score = 0.1946
# Fold ke- 5 Akurasi = 0.1944 Precision = 0.8705 Recall = 0.1944 F1-Score = 0.3245
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8132 Recall = 0.2407 F1-Score = 0.4436
# Fold ke- 7 Akurasi = 0.2500 Precision = 0.8631 Recall = 0.2500 F1-Score = 0.3550
# Fold ke- 8 Akurasi = 0.1944 Precision = 0.8993 Recall = 0.1944 F1-Score = 0.2612
# Fold ke- 9 Akurasi = 0.1389 Precision = 0.7270 Recall = 0.1389 F1-Score = 0.1896
# Fold ke- 10 Akurasi = 0.1759 Precision = 0.8703 Recall = 0.1759 F1-Score = 0.2851
# Avg accuracy = 0.1815 Avg precision= 0.7835 Avg recall= 0.1815 Avg f1 Score= 0.2821
# Akurasi terbaik adalah 0.2777777777777778 pada fold ke- 3
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.1111 Precision = 0.6952 Recall = 0.1111 F1-Score = 0.2405
# Fold ke- 2 Akurasi = 0.0926 Precision = 0.5421 Recall = 0.0926 F1-Score = 0.1776
# Fold ke- 3 Akurasi = 0.2870 Precision = 0.6764 Recall = 0.2870 F1-Score = 0.3462
# Fold ke- 4 Akurasi = 0.1481 Precision = 0.8699 Recall = 0.1481 F1-Score = 0.2182
# Fold ke- 5 Akurasi = 0.2037 Precision = 0.8707 Recall = 0.2037 F1-Score = 0.3451
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8498 Recall = 0.2407 F1-Score = 0.4557
# Fold ke- 7 Akurasi = 0.2407 Precision = 0.8458 Recall = 0.2407 F1-Score = 0.3634
# Fold ke- 8 Akurasi = 0.2037 Precision = 0.8994 Recall = 0.2037 F1-Score = 0.2795
# Fold ke- 9 Akurasi = 0.1667 Precision = 0.7615 Recall = 0.1667 F1-Score = 0.2324
# Fold ke- 10 Akurasi = 0.2037 Precision = 0.8868 Recall = 0.2037 F1-Score = 0.3091
# Avg accuracy = 0.1898 Avg precision= 0.7898 Avg recall= 0.1898 Avg f1 Score= 0.2968
# Akurasi terbaik adalah 0.28703703703703703 pada fold ke- 3
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.1204 Precision = 0.7716 Recall = 0.1204 F1-Score = 0.2307
# Fold ke- 2 Akurasi = 0.1204 Precision = 0.5980 Recall = 0.1204 F1-Score = 0.1573
# Fold ke- 3 Akurasi = 0.2500 Precision = 0.7085 Recall = 0.2500 F1-Score = 0.3117
# Fold ke- 4 Akurasi = 0.1574 Precision = 0.7753 Recall = 0.1574 F1-Score = 0.2288
# Fold ke- 5 Akurasi = 0.2593 Precision = 0.8628 Recall = 0.2593 F1-Score = 0.4044
# Fold ke- 6 Akurasi = 0.2593 Precision = 0.8319 Recall = 0.2593 F1-Score = 0.4754
# Fold ke- 7 Akurasi = 0.2685 Precision = 0.8633 Recall = 0.2685 F1-Score = 0.3649
# Fold ke- 8 Akurasi = 0.2222 Precision = 0.8628 Recall = 0.2222 F1-Score = 0.2992
# Fold ke- 9 Akurasi = 0.2130 Precision = 0.8472 Recall = 0.2130 F1-Score = 0.3529
# Fold ke- 10 Akurasi = 0.2315 Precision = 0.8872 Recall = 0.2315 F1-Score = 0.3651
# Avg accuracy = 0.2102 Avg precision= 0.8009 Avg recall= 0.2102 Avg f1 Score= 0.3190
# Akurasi terbaik adalah 0.26851851851851855 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.1389 Precision = 0.5682 Recall = 0.1389 F1-Score = 0.2384
# Fold ke- 2 Akurasi = 0.1389 Precision = 0.7649 Recall = 0.1389 F1-Score = 0.2182
# Fold ke- 3 Akurasi = 0.2407 Precision = 0.7527 Recall = 0.2407 F1-Score = 0.3674
# Fold ke- 4 Akurasi = 0.1574 Precision = 0.8700 Recall = 0.1574 F1-Score = 0.2418
# Fold ke- 5 Akurasi = 0.2315 Precision = 0.7446 Recall = 0.2315 F1-Score = 0.3369
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8315 Recall = 0.2407 F1-Score = 0.4391
# Fold ke- 7 Akurasi = 0.2870 Precision = 0.8479 Recall = 0.2870 F1-Score = 0.3934
# Fold ke- 8 Akurasi = 0.2315 Precision = 0.8683 Recall = 0.2315 F1-Score = 0.3095
# Fold ke- 9 Akurasi = 0.2500 Precision = 0.8875 Recall = 0.2500 F1-Score = 0.3863
# Fold ke- 10 Akurasi = 0.2315 Precision = 0.8872 Recall = 0.2315 F1-Score = 0.3651
# Avg accuracy = 0.2148 Avg precision= 0.8023 Avg recall= 0.2148 Avg f1 Score= 0.3296
# Akurasi terbaik adalah 0.28703703703703703 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= manhattan
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.1667 Precision = 0.4935 Recall = 0.1667 F1-Score = 0.2731
# Fold ke- 2 Akurasi = 0.1204 Precision = 0.4850 Recall = 0.1204 F1-Score = 0.1670
# Fold ke- 3 Akurasi = 0.2130 Precision = 0.7822 Recall = 0.2130 F1-Score = 0.3185
# Fold ke- 4 Akurasi = 0.1667 Precision = 0.8133 Recall = 0.1667 F1-Score = 0.2517
# Fold ke- 5 Akurasi = 0.2037 Precision = 0.8707 Recall = 0.2037 F1-Score = 0.3451
# Fold ke- 6 Akurasi = 0.2407 Precision = 0.8222 Recall = 0.2407 F1-Score = 0.4372
# Fold ke- 7 Akurasi = 0.3148 Precision = 0.8435 Recall = 0.3148 F1-Score = 0.4091
# Fold ke- 8 Akurasi = 0.2500 Precision = 0.8561 Recall = 0.2500 F1-Score = 0.3221
# Fold ke- 9 Akurasi = 0.2685 Precision = 0.8311 Recall = 0.2685 F1-Score = 0.3764
# Fold ke- 10 Akurasi = 0.2407 Precision = 0.8874 Recall = 0.2407 F1-Score = 0.3777
# Avg accuracy = 0.2185 Avg precision= 0.7685 Avg recall= 0.2185 Avg f1 Score= 0.3278
# Akurasi terbaik adalah 0.3148148148148148 pada fold ke- 7
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 1
# Fold ke- 1 Akurasi = 0.6296 Precision = 0.6394 Recall = 0.6296 F1-Score = 0.6189
# Fold ke- 2 Akurasi = 0.7037 Precision = 0.7147 Recall = 0.7037 F1-Score = 0.6994
# Fold ke- 3 Akurasi = 0.6111 Precision = 0.6381 Recall = 0.6111 F1-Score = 0.6027
# Fold ke- 4 Akurasi = 0.7037 Precision = 0.7514 Recall = 0.7037 F1-Score = 0.7023
# Fold ke- 5 Akurasi = 0.7593 Precision = 0.7673 Recall = 0.7593 F1-Score = 0.7571
# Fold ke- 6 Akurasi = 0.8426 Precision = 0.8607 Recall = 0.8426 F1-Score = 0.8409
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8354 Recall = 0.8148 F1-Score = 0.8064
# Fold ke- 8 Akurasi = 0.7500 Precision = 0.7429 Recall = 0.7500 F1-Score = 0.7338
# Fold ke- 9 Akurasi = 0.7500 Precision = 0.7650 Recall = 0.7500 F1-Score = 0.7445
# Fold ke- 10 Akurasi = 0.7315 Precision = 0.7687 Recall = 0.7315 F1-Score = 0.7220
# Avg accuracy = 0.7296 Avg precision= 0.7483 Avg recall= 0.7296 Avg f1 Score= 0.7228
# Akurasi terbaik adalah 0.8425925925925926 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 3
# Fold ke- 1 Akurasi = 0.7130 Precision = 0.7162 Recall = 0.7130 F1-Score = 0.7036
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7255 Recall = 0.7222 F1-Score = 0.7168
# Fold ke- 3 Akurasi = 0.6574 Precision = 0.6586 Recall = 0.6574 F1-Score = 0.6446
# Fold ke- 4 Akurasi = 0.7593 Precision = 0.7754 Recall = 0.7593 F1-Score = 0.7602
# Fold ke- 5 Akurasi = 0.7315 Precision = 0.7469 Recall = 0.7315 F1-Score = 0.7294
# Fold ke- 6 Akurasi = 0.8611 Precision = 0.8718 Recall = 0.8611 F1-Score = 0.8628
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8329 Recall = 0.8148 F1-Score = 0.8083
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8333 Recall = 0.8241 F1-Score = 0.8157
# Fold ke- 9 Akurasi = 0.7685 Precision = 0.7961 Recall = 0.7685 F1-Score = 0.7665
# Fold ke- 10 Akurasi = 0.7870 Precision = 0.8321 Recall = 0.7870 F1-Score = 0.7790
# Avg accuracy = 0.7639 Avg precision= 0.7789 Avg recall= 0.7639 Avg f1 Score= 0.7587
# Akurasi terbaik adalah 0.8611111111111112 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 5
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7557 Recall = 0.7407 F1-Score = 0.7302
# Fold ke- 2 Akurasi = 0.7130 Precision = 0.7149 Recall = 0.7130 F1-Score = 0.7049
# Fold ke- 3 Akurasi = 0.6296 Precision = 0.6205 Recall = 0.6296 F1-Score = 0.6118
# Fold ke- 4 Akurasi = 0.7685 Precision = 0.7825 Recall = 0.7685 F1-Score = 0.7680
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8021 Recall = 0.7778 F1-Score = 0.7784
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9141 Recall = 0.9074 F1-Score = 0.9075
# Fold ke- 7 Akurasi = 0.8148 Precision = 0.8368 Recall = 0.8148 F1-Score = 0.8092
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8132 Recall = 0.8056 F1-Score = 0.7993
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8203 Recall = 0.7963 F1-Score = 0.7934
# Fold ke- 10 Akurasi = 0.8148 Precision = 0.8569 Recall = 0.8148 F1-Score = 0.8067
# Avg accuracy = 0.7769 Avg precision= 0.7917 Avg recall= 0.7769 Avg f1 Score= 0.7709
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 7
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7933 Recall = 0.7500 F1-Score = 0.7337
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7319 Recall = 0.7222 F1-Score = 0.7147
# Fold ke- 3 Akurasi = 0.6389 Precision = 0.6295 Recall = 0.6389 F1-Score = 0.6203
# Fold ke- 4 Akurasi = 0.7870 Precision = 0.8106 Recall = 0.7870 F1-Score = 0.7910
# Fold ke- 5 Akurasi = 0.7778 Precision = 0.8117 Recall = 0.7778 F1-Score = 0.7758
# Fold ke- 6 Akurasi = 0.9259 Precision = 0.9326 Recall = 0.9259 F1-Score = 0.9259
# Fold ke- 7 Akurasi = 0.8241 Precision = 0.8309 Recall = 0.8241 F1-Score = 0.8167
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8147 Recall = 0.8056 F1-Score = 0.7962
# Fold ke- 9 Akurasi = 0.7870 Precision = 0.8164 Recall = 0.7870 F1-Score = 0.7848
# Fold ke- 10 Akurasi = 0.8519 Precision = 0.8727 Recall = 0.8519 F1-Score = 0.8497
# Avg accuracy = 0.7870 Avg precision= 0.8044 Avg recall= 0.7870 Avg f1 Score= 0.7809
# Akurasi terbaik adalah 0.9259259259259259 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 9
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.7974 Recall = 0.7500 F1-Score = 0.7366
# Fold ke- 2 Akurasi = 0.7407 Precision = 0.7663 Recall = 0.7407 F1-Score = 0.7319
# Fold ke- 3 Akurasi = 0.6667 Precision = 0.6718 Recall = 0.6667 F1-Score = 0.6553
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8330 Recall = 0.8056 F1-Score = 0.8117
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8371 Recall = 0.8056 F1-Score = 0.8035
# Fold ke- 6 Akurasi = 0.9074 Precision = 0.9144 Recall = 0.9074 F1-Score = 0.9074
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8743 Recall = 0.8333 F1-Score = 0.8245
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8198 Recall = 0.8148 F1-Score = 0.8075
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.8049 Recall = 0.7778 F1-Score = 0.7760
# Fold ke- 10 Akurasi = 0.8519 Precision = 0.8712 Recall = 0.8519 F1-Score = 0.8511
# Avg accuracy = 0.7954 Avg precision= 0.8190 Avg recall= 0.7954 Avg f1 Score= 0.7906
# Akurasi terbaik adalah 0.9074074074074074 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 11
# Fold ke- 1 Akurasi = 0.7407 Precision = 0.7905 Recall = 0.7407 F1-Score = 0.7274
# Fold ke- 2 Akurasi = 0.7685 Precision = 0.7910 Recall = 0.7685 F1-Score = 0.7602
# Fold ke- 3 Akurasi = 0.6852 Precision = 0.7126 Recall = 0.6852 F1-Score = 0.6726
# Fold ke- 4 Akurasi = 0.8241 Precision = 0.8509 Recall = 0.8241 F1-Score = 0.8277
# Fold ke- 5 Akurasi = 0.8148 Precision = 0.8313 Recall = 0.8148 F1-Score = 0.8119
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8859 Recall = 0.8796 F1-Score = 0.8791
# Fold ke- 7 Akurasi = 0.8426 Precision = 0.8836 Recall = 0.8426 F1-Score = 0.8338
# Fold ke- 8 Akurasi = 0.8241 Precision = 0.8355 Recall = 0.8241 F1-Score = 0.8164
# Fold ke- 9 Akurasi = 0.7963 Precision = 0.8163 Recall = 0.7963 F1-Score = 0.7944
# Fold ke- 10 Akurasi = 0.8611 Precision = 0.8733 Recall = 0.8611 F1-Score = 0.8593
# Avg accuracy = 0.8037 Avg precision= 0.8271 Avg recall= 0.8037 Avg f1 Score= 0.7983
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 13
# Fold ke- 1 Akurasi = 0.7500 Precision = 0.8050 Recall = 0.7500 F1-Score = 0.7363
# Fold ke- 2 Akurasi = 0.7407 Precision = 0.7660 Recall = 0.7407 F1-Score = 0.7272
# Fold ke- 3 Akurasi = 0.7037 Precision = 0.7363 Recall = 0.7037 F1-Score = 0.6905
# Fold ke- 4 Akurasi = 0.8056 Precision = 0.8475 Recall = 0.8056 F1-Score = 0.8121
# Fold ke- 5 Akurasi = 0.7963 Precision = 0.8206 Recall = 0.7963 F1-Score = 0.7941
# Fold ke- 6 Akurasi = 0.8889 Precision = 0.8976 Recall = 0.8889 F1-Score = 0.8895
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8743 Recall = 0.8333 F1-Score = 0.8245
# Fold ke- 8 Akurasi = 0.8148 Precision = 0.8278 Recall = 0.8148 F1-Score = 0.8083
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.7958 Recall = 0.7778 F1-Score = 0.7730
# Fold ke- 10 Akurasi = 0.8611 Precision = 0.8732 Recall = 0.8611 F1-Score = 0.8614
# Avg accuracy = 0.7972 Avg precision= 0.8244 Avg recall= 0.7972 Avg f1 Score= 0.7917
# Akurasi terbaik adalah 0.8888888888888888 pada fold ke- 6
# ------------------------------------
# Tanpa Stemming
# Nama distance= cosine
# Jumlah K tetangga= 15
# Fold ke- 1 Akurasi = 0.7315 Precision = 0.7903 Recall = 0.7315 F1-Score = 0.7219
# Fold ke- 2 Akurasi = 0.7222 Precision = 0.7622 Recall = 0.7222 F1-Score = 0.7097
# Fold ke- 3 Akurasi = 0.7037 Precision = 0.7435 Recall = 0.7037 F1-Score = 0.6950
# Fold ke- 4 Akurasi = 0.7778 Precision = 0.8236 Recall = 0.7778 F1-Score = 0.7791
# Fold ke- 5 Akurasi = 0.8056 Precision = 0.8282 Recall = 0.8056 F1-Score = 0.8030
# Fold ke- 6 Akurasi = 0.8796 Precision = 0.8853 Recall = 0.8796 F1-Score = 0.8792
# Fold ke- 7 Akurasi = 0.8333 Precision = 0.8678 Recall = 0.8333 F1-Score = 0.8225
# Fold ke- 8 Akurasi = 0.8056 Precision = 0.8230 Recall = 0.8056 F1-Score = 0.7979
# Fold ke- 9 Akurasi = 0.7778 Precision = 0.7969 Recall = 0.7778 F1-Score = 0.7724
# Fold ke- 10 Akurasi = 0.8611 Precision = 0.8706 Recall = 0.8611 F1-Score = 0.8585
# Avg accuracy = 0.7898 Avg precision= 0.8192 Avg recall= 0.7898 Avg f1 Score= 0.7839
# Akurasi terbaik adalah 0.8796296296296297 pada fold ke- 6
# ------------------------------------
# Lama Proses 126.87726354598999 seconds
# CPU times: user 3min 9s, sys: 985 ms, total: 3min 10s
# Wall time: 2min 7s

# %% [markdown]
# ## coba

# %%
X = df['text']
y = df['label'].astype('int')
# X = dfNo['text']
# y = dfNo['label'].astype('int')

# %%
vectorizer = TfidfVectorizer(min_df=3, dtype=np.double, norm='l2', sublinear_tf=True)
# vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import GridSearchCV
#List Hyperparameters that we want to tune.
leaf_size = list(range(1,50))
n_neighbors = list(range(1,30))
p=[1,2]
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Create new KNN object
knn_2 = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)
#Fit the model
best_model = clf.fit(X,y)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])

# %%
df.head()

# %%
# df['label'].head(216).unique()
df2 = df['label'].loc[:215]
df2

# %%
item_counts = df2.value_counts()
print(item_counts)
